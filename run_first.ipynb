# %% [markdown]
# # Run First

# %%
# IMPORTANT: Run this shell before Install Packages and CUDA, cuDNN, Docker, NVIDIA Container toolkit on Jupyter Notebook.
# IMPORTANT: DON'T LEAK YOUR PASSWORD!
from getpass import getpass
import os

def check_passwd():
    if os.path.exists('mypassword'):
        with open('mypassword', 'r') as f:
            passwd=getpass()
            if passwd==f.read():
                return True
            else:
                return False
    else:
        set_passwd()
    
def set_passwd():
     with open('mypassword', 'w') as f:
        passwd=getpass()
        f.write(passwd)

check_passwd()

# %% [markdown]
# ## Install Packages

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get install -y build-essential pandoc gcc g++ software-properties-common bash python3-pip python3-tk python3-dev python3-launchpadlib bash git git-lfs net-tools netcat-openbsd ffmpeg wget curl p7zip-full pkg-config ca-certificates jq libglib2.0-0 libsm6 libgl1 libxrender1 libxext6 libcairo2-dev libgoogle-perftools4 libtcmalloc-minimal4 < mypassword

# %%
# !sudo -S update-ca-certificates < mypassword

# %% [markdown]
# ## Install CUDA

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-ubuntu2404.pin

# %%
# !sudo -S mv cuda-ubuntu2404.pin /etc/apt/preferences.d/cuda-repository-pin-600 < mypassword

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/12.6.2/local_installers/cuda-repo-ubuntu2404-12-6-local_12.6.2-560.35.03-1_amd64.deb

# %%
# !sudo -S dpkg -i cuda-repo-ubuntu2404-12-6-local_12.6.2-560.35.03-1_amd64.deb < mypassword

# %%
# !sudo -S cp /var/cuda-repo-ubuntu2404-12-6-local/cuda-*-keyring.gpg /usr/share/keyrings/ < mypassword

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get -y install cuda-12-6 < mypassword

# %% [markdown]
# ### Install cuDNN

# %%
# !wget https://developer.download.nvidia.com/compute/cudnn/9.5.0/local_installers/cudnn-local-repo-ubuntu2404-9.5.0_1.0-1_amd64.deb

# %%
# !sudo -S dpkg -i cudnn-local-repo-ubuntu2404-9.5.0_1.0-1_amd64.deb < mypassword

# %%
# !sudo -S cp /var/cudnn-local-repo-ubuntu2404-9.5.0/cudnn-*-keyring.gpg /usr/share/keyrings/ < mypassword

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get -y install cudnn < mypassword

# %% [markdown]
# ## Install Conda

# %%
# !curl -O https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh

# %%
# !bash ~/Anaconda3-2024.10-1-Linux-x86_64.sh -b -p $HOME/anaconda3

# %%
# %source ~/anaconda3/bin/activate 
# %conda init --all

# %% [markdown]
# ## Install Pytorch

# %%
# %pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.7 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 96.9 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio
#   Downloading torchaudio-2.5.1-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.6 MB/s eta 0:00:00:00:01
# Collecting nvidia-nccl-cu12==2.21.5
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.3.1.170
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:0000:0100:01
# Collecting fsspec
#   Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 KB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Collecting nvidia-cuda-runtime-cu12==12.4.127
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 63.5 MB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.4.127
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/bean980310/.local/lib/python3.10/site-packages (from torch) (4.12.2)
# Collecting triton==3.1.0
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 7.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.4.5.8
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.6.1.9
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.4.127
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.2 MB/s eta 0:00:0000:0100:01
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 108.5 MB/s eta 0:00:0000:01
# Collecting nvidia-cufft-cu12==11.2.1.3
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12==12.4.127
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.5.147
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 22.1 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 50.6 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 82.0 MB/s eta 0:00:0000:0100:01
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.0 MB/s eta 0:00:0000:01
# Installing collected packages: mpmath, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# Successfully installed filelock-3.16.1 fsspec-2024.12.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-11.0.0 sympy-1.13.1 torch-2.5.1 torchaudio-2.5.1 torchvision-0.20.1 triton-3.1.0

# %%
# %conda install -y pytorch torchvision torchaudio pytorch-cuda=12.4 -c pytorch -c nvidia
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/bean980310/anaconda3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=12.4
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.11.26 |       h06a4308_0         131 KB
#     certifi-2024.12.14         |  py312h06a4308_0         161 KB
#     conda-24.11.2              |  py312h06a4308_0         1.2 MB
#     cuda-cudart-12.4.127       |                0         198 KB  nvidia
#     cuda-cupti-12.4.127        |                0        16.4 MB  nvidia
#     cuda-libraries-12.4.1      |                0           2 KB  nvidia
#     cuda-nvrtc-12.4.127        |                0        21.0 MB  nvidia
#     cuda-nvtx-12.4.127         |                0          58 KB  nvidia
#     cuda-opencl-12.6.77        |                0          25 KB  nvidia
#     cuda-runtime-12.4.1        |                0           2 KB  nvidia
#     cuda-version-12.6          |                3          16 KB  nvidia
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     gmp-6.2.1                  |       h295c915_3         544 KB
#     gnutls-3.6.15              |       he1e5248_0         1.0 MB
#     lame-3.100                 |       h7b6447c_0         323 KB
#     libcublas-12.4.5.8         |                0       309.2 MB  nvidia
#     libcufft-11.2.1.3          |                0       190.5 MB  nvidia
#     libcufile-1.11.1.6         |                0         899 KB  nvidia
#     libcurand-10.3.7.77        |                0        39.7 MB  nvidia
#     libcusolver-11.6.1.9       |                0       114.0 MB  nvidia
#     libcusparse-12.3.1.170     |                0       179.6 MB  nvidia
#     libidn2-2.3.4              |       h5eee18b_0         146 KB
#     libjpeg-turbo-2.0.0        |       h9bf148f_0         950 KB  pytorch
#     libnpp-12.2.5.30           |                0       142.8 MB  nvidia
#     libnvfatbin-12.6.77        |                0         783 KB  nvidia
#     libnvjitlink-12.4.127      |                0        18.2 MB  nvidia
#     libnvjpeg-12.3.1.117       |                0         3.0 MB  nvidia
#     libtasn1-4.19.0            |       h5eee18b_0          63 KB
#     libunistring-0.9.10        |       h27cfd23_0         536 KB
#     libwebp-1.3.2              |       h11a3e52_0          87 KB
#     llvm-openmp-14.0.6         |       h9e868ea_0         4.4 MB
#     nettle-3.7.3               |       hbbd107a_1         809 KB
#     openh264-2.1.1             |       h4ff587b_0         711 KB
#     pytorch-2.5.1              |py3.12_cuda12.4_cudnn9.1.0_0        1.46 GB  pytorch
#     pytorch-cuda-12.4          |       hc786d27_7           7 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-2.5.1           |      py312_cu124         6.3 MB  pytorch
#     torchtriton-3.1.0          |            py312       233.6 MB  pytorch
#     torchvision-0.20.1         |      py312_cu124         8.4 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        2.74 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda-cudart        nvidia/linux-64::cuda-cudart-12.4.127-0
#   cuda-cupti         nvidia/linux-64::cuda-cupti-12.4.127-0
#   cuda-libraries     nvidia/linux-64::cuda-libraries-12.4.1-0
#   cuda-nvrtc         nvidia/linux-64::cuda-nvrtc-12.4.127-0
#   cuda-nvtx          nvidia/linux-64::cuda-nvtx-12.4.127-0
#   cuda-opencl        nvidia/linux-64::cuda-opencl-12.6.77-0
#   cuda-runtime       nvidia/linux-64::cuda-runtime-12.4.1-0
#   cuda-version       nvidia/noarch::cuda-version-12.6-3
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   gmp                pkgs/main/linux-64::gmp-6.2.1-h295c915_3
#   gnutls             pkgs/main/linux-64::gnutls-3.6.15-he1e5248_0
#   lame               pkgs/main/linux-64::lame-3.100-h7b6447c_0
#   libcublas          nvidia/linux-64::libcublas-12.4.5.8-0
#   libcufft           nvidia/linux-64::libcufft-11.2.1.3-0
#   libcufile          nvidia/linux-64::libcufile-1.11.1.6-0
#   libcurand          nvidia/linux-64::libcurand-10.3.7.77-0
#   libcusolver        nvidia/linux-64::libcusolver-11.6.1.9-0
#   libcusparse        nvidia/linux-64::libcusparse-12.3.1.170-0
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libjpeg-turbo      pytorch/linux-64::libjpeg-turbo-2.0.0-h9bf148f_0
#   libnpp             nvidia/linux-64::libnpp-12.2.5.30-0
#   libnvfatbin        nvidia/linux-64::libnvfatbin-12.6.77-0
#   libnvjitlink       nvidia/linux-64::libnvjitlink-12.4.127-0
#   libnvjpeg          nvidia/linux-64::libnvjpeg-12.3.1.117-0
#   libtasn1           pkgs/main/linux-64::libtasn1-4.19.0-h5eee18b_0
#   libunistring       pkgs/main/linux-64::libunistring-0.9.10-h27cfd23_0
#   libwebp            pkgs/main/linux-64::libwebp-1.3.2-h11a3e52_0
#   llvm-openmp        pkgs/main/linux-64::llvm-openmp-14.0.6-h9e868ea_0
#   nettle             pkgs/main/linux-64::nettle-3.7.3-hbbd107a_1
#   openh264           pkgs/main/linux-64::openh264-2.1.1-h4ff587b_0
#   pytorch            pytorch/linux-64::pytorch-2.5.1-py3.12_cuda12.4_cudnn9.1.0_0
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-12.4-hc786d27_7
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/linux-64::torchaudio-2.5.1-py312_cu124
#   torchtriton        pytorch/linux-64::torchtriton-3.1.0-py312
#   torchvision        pytorch/linux-64::torchvision-0.20.1-py312_cu124
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2024.9.24-h06a4308_0 --> 2024.11.26-h06a4308_0
#   certifi                         2024.8.30-py312h06a4308_0 --> 2024.12.14-py312h06a4308_0
#   conda                              24.9.2-py312h06a4308_0 --> 24.11.2-py312h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
# libcublas-12.4.5.8   | 309.2 MB  |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  |                                       |   0%
#
#
# libcufft-11.2.1.3    | 190.5 MB  |                                       |   0%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  |                                       |   0%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  |                                       |   0%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  |                                       |   0%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   |                                       |   0%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 18.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.2        | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.11.1.6   | 899 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.6.77  | 783 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 711 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   |                                       |   0% [A
# libcublas-12.4.5.8   | 309.2 MB  |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  | 2                                     |   1%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | 2                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  |                                       |   0%
# pytorch-2.5.1        | 1.46 GB   | 1                                     |   0%
#
# torchtriton-3.1.0    | 233.6 MB  | #                                     |   3%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #2                                    |   3%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 2                                     |   1%
# libcublas-12.4.5.8   | 309.2 MB  | #3                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | #8                                    |   5%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##2                                   |   6%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 4                                     |   1%
# libcublas-12.4.5.8   | 309.2 MB  | #9                                    |   5%
#
# torchtriton-3.1.0    | 233.6 MB  | ##6                                   |   7%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###3                                  |   9%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 5                                     |   1%
# libcublas-12.4.5.8   | 309.2 MB  | ##5                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ###4                                  |   9%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ###6                                  |  10%
#
#
# pytorch-2.5.1        | 1.46 GB   | 6                                     |   2%
# libcublas-12.4.5.8   | 309.2 MB  | ###2                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ####2                                 |  11%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #####3                                |  15%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 7                                     |   2%
# libcublas-12.4.5.8   | 309.2 MB  | ###8                                  |  11%
#
# torchtriton-3.1.0    | 233.6 MB  | #####                                 |  14%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ######4                               |  17%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 9                                     |   2%
# libcublas-12.4.5.8   | 309.2 MB  | ####5                                 |  12%
#
# torchtriton-3.1.0    | 233.6 MB  | #####8                                |  16%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #######4                              |  20%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ######4                               |  17%
# libcublas-12.4.5.8   | 309.2 MB  | #####2                                |  14%
#
# torchtriton-3.1.0    | 233.6 MB  | ######6                               |  18%
#
#
# pytorch-2.5.1        | 1.46 GB   | #                                     |   3%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | #######2                              |  20%
#
# torchtriton-3.1.0    | 233.6 MB  | #######5                              |  21%
#
#
# pytorch-2.5.1        | 1.46 GB   | #1                                    |   3%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ########1                             |  22%
# libcublas-12.4.5.8   | 309.2 MB  | #####8                                |  16%
#
# pytorch-2.5.1        | 1.46 GB   | #2                                    |   4%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | #########1                            |  25%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##########6                           |  29%
# libcublas-12.4.5.8   | 309.2 MB  | ######4                               |  18%
#
# pytorch-2.5.1        | 1.46 GB   | #4                                    |   4%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###########6                          |  32%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ##########                            |  27%
# libcublas-12.4.5.8   | 309.2 MB  | #######1                              |  19%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########1                           |  27%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ############7                         |  34%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #5                                    |   4%
# libcublas-12.4.5.8   | 309.2 MB  | #######7                              |  21%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #6                                    |   5%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #############7                        |  37%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########                           |  30%
# libcublas-12.4.5.8   | 309.2 MB  | ########3                             |  23%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #8                                    |   5%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##############9                       |  40%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########8                          |  32%
# libcublas-12.4.5.8   | 309.2 MB  | ########9                             |  24%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | #############9                        |  38%
#
# pytorch-2.5.1        | 1.46 GB   | #9                                    |   5%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###############9                      |  43%
# libcublas-12.4.5.8   | 309.2 MB  | #########5                            |  26%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ##############9                       |  40%
#
# pytorch-2.5.1        | 1.46 GB   | ##                                    |   6%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ################9                     |  46%
# libcublas-12.4.5.8   | 309.2 MB  | ##########1                           |  27%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##2                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############3                       |  39%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #################9                    |  49%
# libcublas-12.4.5.8   | 309.2 MB  | ##########7                           |  29%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##3                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############1                      |  41%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##################9                   |  51%
# libcublas-12.4.5.8   | 309.2 MB  | ###########3                          |  31%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##4                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############9                      |  43%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###################9                  |  54%
# libcublas-12.4.5.8   | 309.2 MB  | ###########8                          |  32%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##5                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ################7                     |  45%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ####################9                 |  57%
# libcublas-12.4.5.8   | 309.2 MB  | ############4                         |  34%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ###################7                  |  53%
#
# pytorch-2.5.1        | 1.46 GB   | ##6                                   |   7%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #####################8                |  59%
# libcublas-12.4.5.8   | 309.2 MB  | #############                         |  35%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ####################7                 |  56%
#
# pytorch-2.5.1        | 1.46 GB   | ##8                                   |   8%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ######################8               |  62%
# libcublas-12.4.5.8   | 309.2 MB  | #############5                        |  37%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | #####################7                |  59%
#
# pytorch-2.5.1        | 1.46 GB   | ##9                                   |   8%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #######################8              |  64%
# libcublas-12.4.5.8   | 309.2 MB  | ##############1                       |  38%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################9                  |  54%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ########################8             |  67%
# libcublas-12.4.5.8   | 309.2 MB  | ##############7                       |  40%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###1                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################6                 |  56%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #########################8            |  70%
# libcublas-12.4.5.8   | 309.2 MB  | ###############2                      |  41%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###3                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | #####################4                |  58%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##########################8           |  72%
# libcublas-12.4.5.8   | 309.2 MB  | ###############8                      |  43%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###4                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ######################2               |  60%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###########################8          |  75%
# libcublas-12.4.5.8   | 309.2 MB  | ################4                     |  44%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###5                                  |  10%
#
# torchtriton-3.1.0    | 233.6 MB  | #######################               |  62%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ############################8         |  78%
# libcublas-12.4.5.8   | 309.2 MB  | ################9                     |  46%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###6                                  |  10%
#
# torchtriton-3.1.0    | 233.6 MB  | #######################8              |  65%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #############################7        |  81%
# libcublas-12.4.5.8   | 309.2 MB  | #################5                    |  47%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###7                                  |  10%
#
# torchtriton-3.1.0    | 233.6 MB  | ########################6             |  67%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##############################7       |  83%
# libcublas-12.4.5.8   | 309.2 MB  | ##################1                   |  49%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###9                                  |  11%
#
# torchtriton-3.1.0    | 233.6 MB  | #########################4            |  69%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###############################7      |  86%
# libcublas-12.4.5.8   | 309.2 MB  | ##################6                   |  50%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####                                  |  11%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########################2           |  71%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ################################7     |  89%
# libcublas-12.4.5.8   | 309.2 MB  | ###################2                  |  52%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####1                                 |  11%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########################9           |  73%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | #################################7    |  91%
# libcublas-12.4.5.8   | 309.2 MB  | ###################7                  |  53%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####2                                 |  12%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########################7          |  75%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##################################7   |  94%
# libcublas-12.4.5.8   | 309.2 MB  | ####################3                 |  55%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####3                                 |  12%
#
# torchtriton-3.1.0    | 233.6 MB  | ############################5         |  77%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ###################################7  |  97%
# libcublas-12.4.5.8   | 309.2 MB  | ####################8                 |  56%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####5                                 |  12%
#
# torchtriton-3.1.0    | 233.6 MB  | #############################3        |  79%
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ####################################7 |  99%
# libcublas-12.4.5.8   | 309.2 MB  | #####################4                |  58%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####6                                 |  13%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############################1       |  81%
# libcublas-12.4.5.8   | 309.2 MB  | ######################1               |  60%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####7                                 |  13%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############################       |  84%
# pytorch-2.5.1        | 1.46 GB   | ####9                                 |  13%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############################9      |  86%
# pytorch-2.5.1        | 1.46 GB   | #####                                 |  14%
#
# torchtriton-3.1.0    | 233.6 MB  | ################################8     |  89%
# pytorch-2.5.1        | 1.46 GB   | #####1                                |  14%
#
# torchtriton-3.1.0    | 233.6 MB  | #################################8    |  91%
# pytorch-2.5.1        | 1.46 GB   | #####3                                |  14%
#
# torchtriton-3.1.0    | 233.6 MB  | ##################################7   |  94%
# pytorch-2.5.1        | 1.46 GB   | #####4                                |  15%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################################7  |  97%
# pytorch-2.5.1        | 1.46 GB   | #####6                                |  15%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################################6 |  99%
# pytorch-2.5.1        | 1.46 GB   | #####7                                |  16%
# pytorch-2.5.1        | 1.46 GB   | #####9                                |  16%
# pytorch-2.5.1        | 1.46 GB   | ######                                |  16%
# pytorch-2.5.1        | 1.46 GB   | ######2                               |  17%
# pytorch-2.5.1        | 1.46 GB   | ######4                               |  17%
# pytorch-2.5.1        | 1.46 GB   | ######5                               |  18%
# pytorch-2.5.1        | 1.46 GB   | ######7                               |  18%
# pytorch-2.5.1        | 1.46 GB   | ######9                               |  19%
# pytorch-2.5.1        | 1.46 GB   | #######                               |  19%
# pytorch-2.5.1        | 1.46 GB   | #######2                              |  20%
# pytorch-2.5.1        | 1.46 GB   | #######3                              |  20%
# pytorch-2.5.1        | 1.46 GB   | ########8                             |  24%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  |                                       |   0%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  |                                       |   0%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   |                                       |   0%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########                             |  24%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | 9                                     |   3%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | #1                                    |   3%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ###                                   |   8%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   | #####9                                |  16%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #8                                    |   5%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ##2                                   |   6%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ######                                |  16%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########2                            |  25%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##7                                   |   7%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | #########1                            |  25%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   | ##################                    |  49%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ###6                                  |  10%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ####5                                 |  12%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ############3                         |  33%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########3                            |  25%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ####4                                 |  12%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | #####6                                |  15%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   | ##############################6       |  83%
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########4                            |  26%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ######9                               |  19%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   | ####################################5 |  99%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ######2                               |  17%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ########2                             |  22%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########6                            |  26%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #######2                              |  20%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | #########5                            |  26%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########7                            |  26%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ########3                             |  23%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ###########                           |  30%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########8                            |  27%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #########4                            |  26%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ############3                         |  33%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #########9                            |  27%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##########5                           |  29%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | #############7                        |  37%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########                            |  27%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ###########7                          |  32%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ###############2                      |  41%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########1                           |  27%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ############8                         |  35%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ################5                     |  45%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########2                           |  28%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #############9                        |  38%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ##################                    |  49%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########3                           |  28%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ###############                       |  41%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ###################4                  |  52%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########4                           |  28%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ################                      |  43%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########5                           |  29%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #################2                    |  47%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########6                           |  29%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##################4                   |  50%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########8                           |  29%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   |                                       |   0%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##########9                           |  30%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #####################                 |  57%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   | ##########                            |  27%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########                           |  30%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   | #####################1                |  57%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ######################2               |  60%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   | ################################7     |  89%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #######################5              |  64%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########3                          |  31%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ########################9             |  67%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    |                                       |   0%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##########################4           |  71%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ######################4               |  61%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ###########################8          |  75%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########7                          |  32%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #############################1        |  79%
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########8                          |  32%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##############################5       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########9                          |  32%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############1                         |  33%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.2        | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    | 6                                     |   2%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.11.1.6   | 899 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############3                         |  33%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 711 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.6.77  | 783 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####################################8 | 100% [A
#
#
# libcufft-11.2.1.3    | 190.5 MB  | ##################################### | 100%
#
#
#
# libcusparse-12.3.1.1 | 179.6 MB  | ##################################### | 100%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 21.0 MB   | ##################################### | 100%
#
#
#
#
#
#
# libcurand-10.3.7.77  | 39.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 18.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 16.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ##################################### | 100%
#
# torchtriton-3.1.0    | 233.6 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.2        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.2        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.11.1.6   | 899 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.11.1.6   | 899 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 711 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.1.1       | 711 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.6.77  | 783 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.6.77  | 783 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusolver-11.6.1.9 | 114.0 MB  | ##################################### | 100%
#
#
#
#
# libnpp-12.2.5.30     | 142.8 MB  | ##################################### | 100%
# pytorch-2.5.1        | 1.46 GB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Install Huggingface

# %%
# %pip install huggingface huggingface-hub transformers diffusers safetensors
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting huggingface
#   Downloading huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 KB 12.3 MB/s eta 0:00:0000:01
# Collecting transformers
#   Downloading transformers-4.47.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 46.0 MB/s eta 0:00:0000:010:01
# Collecting diffusers
#   Downloading diffusers-0.32.1-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 71.0 MB/s eta 0:00:00:00:01
# Collecting safetensors
#   Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 KB 184.1 kB/s eta 0:00:0000:01
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub) (5.4.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface-hub) (2.25.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/bean980310/.local/lib/python3.10/site-packages (from huggingface-hub) (4.12.2)
# Requirement already satisfied: filelock in /home/bean980310/.local/lib/python3.10/site-packages (from huggingface-hub) (3.16.1)
# Collecting tqdm>=4.42.1
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /home/bean980310/.local/lib/python3.10/site-packages (from huggingface-hub) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /home/bean980310/.local/lib/python3.10/site-packages (from huggingface-hub) (24.2)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 95.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /home/bean980310/.local/lib/python3.10/site-packages (from transformers) (2.2.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from diffusers) (4.6.4)
# Requirement already satisfied: Pillow in /home/bean980310/.local/lib/python3.10/site-packages (from diffusers) (11.0.0)
# Installing collected packages: huggingface, tqdm, safetensors, regex, huggingface-hub, tokenizers, diffusers, transformers
# Successfully installed diffusers-0.32.1 huggingface-0.0.1 huggingface-hub-0.27.0 regex-2024.11.6 safetensors-0.4.5 tokenizers-0.21.0 tqdm-4.67.1 transformers-4.47.1

# %%
# %conda install -y huggingface_hub transformers safetensors -c huggingface
# Out:
# Channels:
#  - huggingface
#  - defaults
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/bean980310/anaconda3
#
#   added / updated specs:
#     - huggingface_hub
#     - safetensors
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     datasets-3.2.0             |             py_0         337 KB  huggingface
#     huggingface_hub-0.27.0     |             py_0         432 KB  huggingface
#     multiprocess-0.70.15       |  py312h06a4308_0         323 KB
#     python-xxhash-2.0.2        |  py312h5eee18b_1          20 KB
#     safetensors-0.4.5          |  py312hc50d6dc_1         448 KB
#     tokenizers-0.20.1          |  py312h526025d_1         2.3 MB
#     transformers-4.45.2        |  py312h06a4308_0        23.6 MB
#     xxhash-0.8.0               |       h7f8727e_3          83 KB
#     ------------------------------------------------------------
#                                            Total:        27.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   datasets           huggingface/noarch::datasets-3.2.0-py_0
#   huggingface_hub    huggingface/noarch::huggingface_hub-0.27.0-py_0
#   multiprocess       pkgs/main/linux-64::multiprocess-0.70.15-py312h06a4308_0
#   python-xxhash      pkgs/main/linux-64::python-xxhash-2.0.2-py312h5eee18b_1
#   safetensors        pkgs/main/linux-64::safetensors-0.4.5-py312hc50d6dc_1
#   tokenizers         pkgs/main/linux-64::tokenizers-0.20.1-py312h526025d_1
#   transformers       pkgs/main/linux-64::transformers-4.45.2-py312h06a4308_0
#   xxhash             pkgs/main/linux-64::xxhash-0.8.0-h7f8727e_3
#
#
#
# Downloading and Extracting Packages:
# transformers-4.45.2  | 23.6 MB   |                                       |   0%
# tokenizers-0.20.1    | 2.3 MB    |                                       |   0%
#
# safetensors-0.4.5    | 448 KB    |                                       |   0%
#
#
# huggingface_hub-0.27 | 432 KB    |                                       |   0%
#
#
#
# datasets-3.2.0       | 337 KB    |                                       |   0%
#
#
#
#
# multiprocess-0.70.15 | 323 KB    |                                       |   0%
#
#
#
#
#
# xxhash-0.8.0         | 83 KB     |                                       |   0%
#
#
#
#
#
#
# python-xxhash-2.0.2  | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
# dataclasses-0.8      | 8 KB      |                                       |   0%
#
# transformers-4.45.2  | 23.6 MB   | #####1                                |  14%
#
#
#
#
# multiprocess-0.70.15 | 323 KB    | ##################################### | 100%
#
# safetensors-0.4.5    | 448 KB    | ##################################### | 100%
#
# safetensors-0.4.5    | 448 KB    | ##################################### | 100%
# tokenizers-0.20.1    | 2.3 MB    | ##################################### | 100%
# tokenizers-0.20.1    | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
# xxhash-0.8.0         | 83 KB     | #######1                              |  19%
#
#
#
#
#
# xxhash-0.8.0         | 83 KB     | ##################################### | 100%
#
#
#
#
#
#
# python-xxhash-2.0.2  | 20 KB     | #############################1        |  79%
#
#
#
#
#
#
# python-xxhash-2.0.2  | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
#
#
#
#
#
# transformers-4.45.2  | 23.6 MB   | #############2                        |  36%
#
#
#
#
#
#
# python-xxhash-2.0.2  | 20 KB     | ##################################### | 100%
#
#
#
#
# multiprocess-0.70.15 | 323 KB    | ##################################### | 100%
#
#
#
#
# multiprocess-0.70.15 | 323 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
# transformers-4.45.2  | 23.6 MB   | ###################################7  |  97%
#
#
# huggingface_hub-0.27 | 432 KB    | ##################################### | 100%
#
#
# transformers-4.45.2  | 23.6 MB   | ##################################### | 100%
#
#
# huggingface_hub-0.27 | 432 KB    | ##################################### | 100%
#
#
#
# datasets-3.2.0       | 337 KB    | ##################################### | 100%
#
#
#
# datasets-3.2.0       | 337 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install -y diffusers -c conda-forge
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - nvidia
#  - huggingface
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/bean980310/anaconda3
#
#   added / updated specs:
#     - diffusers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     conda-24.11.2              |  py312h7900ff3_0         1.1 MB  conda-forge
#     diffusers-0.32.1           |     pyhd8ed1ab_0         831 KB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     libexpat-2.6.3             |       h5888daf_0          72 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libnsl-2.0.1               |       hd590300_0          33 KB  conda-forge
#     libsqlite-3.46.0           |       hde9e2c9_0         845 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_1          53 KB  conda-forge
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libzlib-1.2.13             |       h4ab18f5_6          60 KB  conda-forge
#     numba-0.60.0               |  py312h83e6fd3_0         5.4 MB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     python-3.12.2              |hab00c5b_0_cpython        30.8 MB  conda-forge
#     python_abi-3.12            |          5_cp312           6 KB  conda-forge
#     zlib-1.2.13                |       h4ab18f5_6          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        47.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   diffusers          conda-forge/noarch::diffusers-0.32.1-pyhd8ed1ab_0
#   libexpat           conda-forge/linux-64::libexpat-2.6.3-h5888daf_0
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.0-hde9e2c9_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h4ab18f5_6
#   python_abi         conda-forge/linux-64::python_abi-3.12-5_cp312
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.11.26~ --> conda-forge::ca-certificates-2024.12.14-hbcca054_0
#   fontconfig         pkgs/main::fontconfig-2.14.1-h4c34cd2~ --> conda-forge::fontconfig-2.14.2-h14ed4e7_0
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-14.2.0-h69a702a_1
#   libgomp              pkgs/main::libgomp-11.2.0-h1234567_1 --> conda-forge::libgomp-14.2.0-h77fa898_1
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-14.2.0-h4852527_1
#   libuuid              pkgs/main::libuuid-1.41.5-h5eee18b_0 --> conda-forge::libuuid-2.38.1-h0b41bf4_0
#   openssl              pkgs/main::openssl-3.0.15-h5eee18b_0 --> conda-forge::openssl-3.4.0-hb9d3cd8_0
#   zlib                    pkgs/main::zlib-1.2.13-h5eee18b_1 --> conda-forge::zlib-1.2.13-h4ab18f5_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-5.1-1_gnu --> conda-forge::_openmp_mutex-4.5-2_gnu
#   certifi            pkgs/main/linux-64::certifi-2024.12.1~ --> conda-forge/noarch::certifi-2024.12.14-pyhd8ed1ab_0
#   conda              pkgs/main::conda-24.11.2-py312h06a430~ --> conda-forge::conda-24.11.2-py312h7900ff3_0
#   numba              pkgs/main::numba-0.60.0-py312h526ad5a~ --> conda-forge::numba-0.60.0-py312h83e6fd3_0
#   python                pkgs/main::python-3.12.7-h5148396_0 --> conda-forge::python-3.12.2-hab00c5b_0_cpython
#
#
#
# Downloading and Extracting Packages:
# python-3.12.2        | 30.8 MB   |                                       |   0%
# numba-0.60.0         | 5.4 MB    |                                       |   0%
#
# libstdcxx-14.2.0     | 3.7 MB    |                                       |   0%
#
#
# openssl-3.4.0        | 2.8 MB    |                                       |   0%
#
#
#
# conda-24.11.2        | 1.1 MB    |                                       |   0%
#
#
#
#
# libsqlite-3.46.0     | 845 KB    |                                       |   0%
#
#
#
#
#
# diffusers-0.32.1     | 831 KB    |                                       |   0%
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    |                                       |   0%
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 266 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 72 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuuid-2.38.1       | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      |                                       |   0%
#
#
#
# conda-24.11.2        | 1.1 MB    | ##################################### | 100%
# numba-0.60.0         | 5.4 MB    | ###5                                  |   9%
#
# python-3.12.2        | 30.8 MB   | #8                                    |   5%
#
#
# openssl-3.4.0        | 2.8 MB    | 2                                     |   1%
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | 7                                     |   2%
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | ##################################### | 100%
# python-3.12.2        | 30.8 MB   | #######4                              |  20%
#
#
#
#
#
# diffusers-0.32.1     | 831 KB    | 7                                     |   2%
#
# libstdcxx-14.2.0     | 3.7 MB    | ##################################### | 100%
#
# libstdcxx-14.2.0     | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
# diffusers-0.32.1     | 831 KB    | ##################################### | 100%
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | ##################################### | 100%
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | ##################################### | 100%
#
#
# openssl-3.4.0        | 2.8 MB    | ##################################### | 100%
#
#
# openssl-3.4.0        | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | 7                                     |   2%
#
#
#
#
#
#
#
# python-3.12.2        | 30.8 MB   | ############6                         |  34%
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 266 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 266 KB    | ##################################### | 100%
# numba-0.60.0         | 5.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 30.8 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 72 KB     | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuuid-2.38.1       | 33 KB     | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuuid-2.38.1       | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 30.8 MB   | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ##################################### | 100%
#
# python-3.12.2        | 30.8 MB   | ################################3     |  87%
#
#
#
# conda-24.11.2        | 1.1 MB    | ##################################### | 100%
#
#
#
# conda-24.11.2        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | ##################################### | 100%
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | ##################################### | 100%
#
#
# openssl-3.4.0        | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libgomp-14.2.0       | 450 KB    | ##################################### | 100%
#
#
#
#
#
# diffusers-0.32.1     | 831 KB    | ##################################### | 100%
#
#
#
#
#
# diffusers-0.32.1     | 831 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 266 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 266 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 30.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuuid-2.38.1       | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuuid-2.38.1       | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install huggingface
# Out:
# DEPRECATION: Loading egg at /home/bean980310/anaconda3/lib/python3.12/site-packages/huggingface_hub-0.27.0-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting huggingface
#   Downloading huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# Downloading huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Installing collected packages: huggingface
# Successfully installed huggingface-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Install Tensorflow

# %%
# %pip install tensorflow tensorboard tensorboardx
# Out:
# DEPRECATION: Loading egg at /home/bean980310/anaconda3/lib/python3.12/site-packages/huggingface_hub-0.27.0-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tensorboard
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardx
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-24.12.23-py2.py3-none-any.whl.metadata (876 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.68.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: markdown>=2.6.8 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorboard) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /home/bean980310/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (615.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 MB 55.2 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 16.0 MB/s eta 0:00:00ta 0:00:01
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.12.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.68.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 85.4 MB/s eta 0:00:00
# Downloading keras-3.7.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 115.8 MB/s eta 0:00:0000:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.4 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 94.0 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorboardx, tensorboard-data-server, optree, opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.12.23 gast-0.6.0 google-pasta-0.2.0 grpcio-1.68.1 keras-3.7.0 libclang-18.1.1 ml-dtypes-0.4.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.13.1 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 tensorflow-2.18.0 termcolor-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Install onnxruntime

# %%
# %pip install onnxruntime-gpu onnx
# Out:
# DEPRECATION: Loading egg at /home/bean980310/anaconda3/lib/python3.12/site-packages/huggingface_hub-0.27.0-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting onnx
#   Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /home/bean980310/anaconda3/lib/python3.12/site-packages (from onnxruntime-gpu) (24.12.23)
# Requirement already satisfied: numpy>=1.21.6 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from onnxruntime-gpu) (1.26.4)
# Requirement already satisfied: packaging in /home/bean980310/anaconda3/lib/python3.12/site-packages (from onnxruntime-gpu) (24.1)
# Requirement already satisfied: protobuf in /home/bean980310/anaconda3/lib/python3.12/site-packages (from onnxruntime-gpu) (4.25.3)
# Requirement already satisfied: sympy in /home/bean980310/anaconda3/lib/python3.12/site-packages (from onnxruntime-gpu) (1.13.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Downloading onnxruntime_gpu-1.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (291.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 43.1 MB/s eta 0:00:0000:0100:01
# Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 39.9 MB/s eta 0:00:00a 0:00:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: onnx, humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.17.0 onnxruntime-gpu-1.20.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Install CivitAI Model Downloader

# %%
# %pip install civitai-model-downloader
# Out:
# DEPRECATION: Loading egg at /home/bean980310/anaconda3/lib/python3.12/site-packages/huggingface_hub-0.27.0-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting civitai-model-downloader
#   Downloading civitai_model_downloader-0.4.0-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: requests in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-model-downloader) (2.32.3)
# Requirement already satisfied: tqdm in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-model-downloader) (4.66.5)
# Requirement already satisfied: ipywidgets in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-model-downloader) (7.8.1)
# Requirement already satisfied: appdirs in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-model-downloader) (1.4.4)
# Requirement already satisfied: urllib3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-model-downloader) (2.2.3)
# Collecting civitai-py (from civitai-model-downloader)
#   Downloading civitai_py-0.1.10-py3-none-any.whl.metadata (15 kB)
# Collecting civitai (from civitai-model-downloader)
#   Downloading civitai-1.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting typer (from civitai-model-downloader)
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests->civitai-model-downloader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests->civitai-model-downloader) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from requests->civitai-model-downloader) (2024.12.14)
# Requirement already satisfied: httpx>=0.23.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-py->civitai-model-downloader) (0.27.0)
# Requirement already satisfied: pydantic>=2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-py->civitai-model-downloader) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from civitai-py->civitai-model-downloader) (4.11.0)
# Requirement already satisfied: comm>=0.1.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipywidgets->civitai-model-downloader) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from typer->civitai-model-downloader) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer->civitai-model-downloader)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from typer->civitai-model-downloader) (13.7.1)
# Requirement already satisfied: anyio in /home/bean980310/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.3->civitai-py->civitai-model-downloader) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /home/bean980310/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.3->civitai-py->civitai-model-downloader) (1.0.2)
# Requirement already satisfied: sniffio in /home/bean980310/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.3->civitai-py->civitai-model-downloader) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.3->civitai-py->civitai-model-downloader) (0.14.0)
# Requirement already satisfied: decorator in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (2.15.1)
# Requirement already satisfied: stack-data in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets->civitai-model-downloader) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from pydantic>=2->civitai-py->civitai-model-downloader) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from pydantic>=2->civitai-py->civitai-model-downloader) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer->civitai-model-downloader) (2.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (7.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->civitai-model-downloader) (0.1.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (6.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.7.0)
# Requirement already satisfied: wcwidth in /home/bean980310/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.2.5)
# Requirement already satisfied: executing in /home/bean980310/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.8.3)
# Requirement already satisfied: asttokens in /home/bean980310/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (2.0.5)
# Requirement already satisfied: pure-eval in /home/bean980310/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (0.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.0.4)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (75.1.0)
# Requirement already satisfied: babel>=2.10 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (4.23.0)
# Requirement already satisfied: six in /home/bean980310/anaconda3/lib/python3.12/site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets->civitai-model-downloader) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/bean980310/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2024.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.6.7)
# Requirement already satisfied: nest-asyncio in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.6.0)
# Requirement already satisfied: psutil in /home/bean980310/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (4.1.0)
# Requirement already satisfied: defusedxml in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.16.2)
# Requirement already satisfied: webencodings in /home/bean980310/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.5)
# Requirement already satisfied: pycparser in /home/bean980310/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/bean980310/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->civitai-model-downloader) (1.2.3)
# Downloading civitai_model_downloader-0.4.0-py3-none-any.whl (57 kB)
# Downloading civitai-1.0.0-py3-none-any.whl (6.1 kB)
# Downloading civitai_py-0.1.10-py3-none-any.whl (61 kB)
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, shellingham, fqdn, civitai, typer, isoduration, civitai-py, civitai-model-downloader
# Successfully installed civitai-1.0.0 civitai-model-downloader-0.4.0 civitai-py-0.1.10 fqdn-1.5.1 isoduration-20.11.0 shellingham-1.5.4 typer-0.15.1 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## configure API key

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from civitai_downloader import login

login()
# Out:
# Token file saved to /home/bean980310/.civitai/config.
# '19825f021991cd8c7685bc2f7fee3b24'

# %% [markdown]
# ## Install Docker Engine

# %%
# !sudo -S install -m 0755 -d /etc/apt/keyrings < mypassword
# !sudo -S curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc < mypassword
# !sudo -S chmod a+r /etc/apt/keyrings/docker.asc < mypassword

# %%
# !echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
  $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
  xargs -a mypassword | sudo -S tee /etc/apt/sources.list.d/docker.list > /dev/null
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin < mypassword

# %%
# !sudo -S groupadd docker < mypassword

# %%
# !sudo -S usermod -aG docker $USER < mypassword

# %% [markdown]
# ### Install NVIDIA Container toolkit

# %%
# !curl -fsSL https://nvidia.github.io/libnvidia-container/gpgkey | sudo -S gpg --dearmor -o /usr/share/keyrings/nvidia-container-toolkit-keyring.gpg < mypassword \
  && curl -s -L https://nvidia.github.io/libnvidia-container/stable/deb/nvidia-container-toolkit.list | \
    sed 's#deb https://#deb [signed-by=/usr/share/keyrings/nvidia-container-toolkit-keyring.gpg] https://#g' | \
    sudo -S tee /etc/apt/sources.list.d/nvidia-container-toolkit.list < mypassword

# %%
# !sed -i -e '/experimental/ s/^#//g' /etc/apt/sources.list.d/nvidia-container-toolkit.list

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get install -y nvidia-container-toolkit < mypassword

# %%
# !sudo -S nvidia-ctk runtime configure --runtime=docker < mypassword

# %%
# !sudo -S systemctl restart docker < mypassword
