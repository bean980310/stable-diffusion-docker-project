# %% [markdown]
# # Run First

# %%
# IMPORTANT: Run this shell before Install Packages and CUDA, cuDNN, Docker, NVIDIA Container toolkit on Jupyter Notebook.
# IMPORTANT: DON'T LEAK YOUR PASSWORD!
from getpass import getpass
import os

def check_passwd():
    if os.path.exists('mypassword'):
        with open('mypassword', 'r') as f:
            passwd=getpass()
            if passwd==f.read():
                return True
            else:
                return False
    else:
        set_passwd()
    
def set_passwd():
     with open('mypassword', 'w') as f:
        passwd=getpass()
        f.write(passwd)

check_passwd()

# %% [markdown]
# ## Install Packages

# %%
# !sudo -S apt-get update < mypassword
# Out:
# Get:1 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ InRelease
# Ign:1 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ InRelease
# Get:2 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Release
# Ign:2 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Release
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Ign:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Ign:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Get:3 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Sources
# Get:4 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Packages [170 kB]
# Get:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Ign:5 file:/usr/share/doca-host-2.8.0-204000-24.07-ubuntu2204/repo main/ Translation-en
# Hit:6 http://azure.archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://azure.archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://azure.archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 http://azure.archive.ubuntu.com/ubuntu jammy-security InRelease
# Hit:10 https://packages.microsoft.com/repos/amlfs-jammy jammy InRelease
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:12 https://packages.microsoft.com/repos/microsoft-ubuntu-jammy-prod jammy InRelease
# Hit:13 https://packages.microsoft.com/repos/slurm-ubuntu-jammy insiders InRelease
# Reading package lists... Done

# %%
# !sudo -S apt-get install -y build-essential pandoc gcc g++ software-properties-common bash python3-pip python3-tk python3-dev python3-launchpadlib bash git git-lfs net-tools netcat-openbsd ffmpeg wget curl p7zip-full pkg-config ca-certificates jq libglib2.0-0 libsm6 libgl1 libxrender1 libxext6 libcairo2-dev libgoogle-perftools4 libtcmalloc-minimal4 < mypassword
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# g++ is already the newest version (4:11.2.0-1ubuntu1).
# g++ set to manually installed.
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gcc set to manually installed.
# jq is already the newest version (1.6-2.1ubuntu3).
# libgl1 is already the newest version (1.4.0-1).
# libgl1 set to manually installed.
# libsm6 is already the newest version (2:1.2.3-1build2).
# libsm6 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxext6 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libxrender1 set to manually installed.
# net-tools is already the newest version (1.60+git20181103.0eebece-1ubuntu5).
# netcat-openbsd is already the newest version (1.218-4ubuntu1).
# netcat-openbsd set to manually installed.
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# python3-launchpadlib is already the newest version (1.10.16-1).
# python3-launchpadlib set to manually installed.
# bash is already the newest version (5.1-6ubuntu1.1).
# ca-certificates is already the newest version (20240203~22.04.1).
# ca-certificates set to manually installed.
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# git set to manually installed.
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# software-properties-common is already the newest version (0.99.22.9).
# software-properties-common set to manually installed.
# wget is already the newest version (1.21.2-2ubuntu1.1).
# The following packages were automatically installed and are no longer required:
#   dpcp hcoll ibacm ibarr ibdump ibsim ibsim-doc ibutils2 ibverbs-providers
#   ibverbs-utils infiniband-diags iser-dkms isert-dkms kernel-mft-dkms knem
#   knem-dkms libfuse2 libibmad-dev libibmad5 libibnetdisc5 libibumad-dev
#   libibumad3 libibverbs-dev libibverbs1 libopensm libopensm-devel
#   librdmacm-dev librdmacm1 libxpmem-dev libxpmem0 mft mlnx-ethtool
#   mlnx-iproute2 mlnx-ofed-kernel-dkms mlnx-ofed-kernel-utils mlnx-tools
#   mpitests ofed-scripts opensm opensm-doc perftest rdma-core rdmacm-utils
#   rshim sharp srp-dkms srptools ucx xpmem xpmem-dkms
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   blt fontconfig i965-va-driver intel-media-va-driver libaacs0 libaom3 libass9
#   libasyncns0 libavc1394-0 libavcodec58 libavdevice58 libavfilter7
#   libavformat58 libavutil56 libbdplus0 libbluray2 libbrotli-dev libbs2b0
#   libcaca0 libcairo-gobject2 libcairo-script-interpreter2 libcdio-cdda2
#   libcdio-paranoia2 libcdio19 libchromaprint1
#   libcmark-gfm-extensions0.29.0.gfm.3 libcmark-gfm0.29.0.gfm.3 libcodec2-1.0
#   libcurl4 libdatrie1 libdav1d5 libdc1394-25 libdecor-0-0
#   libdecor-0-plugin-1-cairo libffi-dev libflac8 libflite1 libfontconfig-dev
#   libfontconfig1-dev libfreetype-dev libfreetype6-dev libgdk-pixbuf-2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libglib2.0-bin libglib2.0-dev
#   libglib2.0-dev-bin libgme0 libgsm1 libice-dev libiec61883-0 libigdgmm12
#   libjack-jackd2-0 liblilv-0-0 libmfx1 libmp3lame0 libmpg123-0 libmysofa1
#   libnorm1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0
#   libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0 libpcre16-3
#   libpcre3-dev libpcre32-3 libpcrecpp0v5 libpgm-5.3-0 libpixman-1-dev
#   libpng-dev libpng-tools libpocketsphinx3 libpostproc55 libpthread-stubs0-dev
#   libpulse0 librabbitmq4 libraw1394-11 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libserd-0-0 libshine3 libsm-dev
#   libsnappy1v5 libsndfile1 libsndio7.0 libsord-0-0 libsoxr0 libspeex1
#   libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls libssh-gcrypt-4 libswresample3
#   libswscale5 libthai-data libthai0 libtheora0 libtwolame0 libudfread0
#   libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx7 libwayland-cursor0 libwayland-egl1
#   libwebpmux3 libx11-dev libx264-163 libx265-199 libxau-dev libxcb-render0-dev
#   libxcb-shm0-dev libxcb1-dev libxcursor1 libxdmcp-dev libxext-dev
#   libxrender-dev libxvidcore4 libzimg2 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers p7zip pandoc-data pocketsphinx-en-us
#   tk8.6-blt2.5 va-driver-all vdpau-driver-all x11proto-dev xorg-sgml-doctools
#   xtrans-dev
# Suggested packages:
#   blt-demo ffmpeg-doc i965-va-driver-shaders libcuda1 libnvcuvid1
#   libnvidia-encode1 libbluray-bdj libcairo2-doc freetype2-doc
#   libgirepository1.0-dev libglib2.0-doc libxml2-utils libice-doc jackd2
#   libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin xdg-utils
#   serdi libsm-doc sndiod sordi speex libx11-doc libxcb-doc libxext-doc
#   p7zip-rar texlive-latex-recommended texlive-xetex texlive-luatex
#   pandoc-citeproc texlive-latex-extra context wkhtmltopdf groff ghc nodejs php
#   python ruby r-base-core libjs-mathjax libjs-katex
#   citation-style-language-styles tix python3-tk-dbg libvdpau-va-gl1
# The following NEW packages will be installed:
#   blt ffmpeg fontconfig git-lfs i965-va-driver intel-media-va-driver libaacs0
#   libaom3 libass9 libasyncns0 libavc1394-0 libavcodec58 libavdevice58
#   libavfilter7 libavformat58 libavutil56 libbdplus0 libbluray2 libbrotli-dev
#   libbs2b0 libcaca0 libcairo-gobject2 libcairo-script-interpreter2
#   libcairo2-dev libcdio-cdda2 libcdio-paranoia2 libcdio19 libchromaprint1
#   libcmark-gfm-extensions0.29.0.gfm.3 libcmark-gfm0.29.0.gfm.3 libcodec2-1.0
#   libdatrie1 libdav1d5 libdc1394-25 libdecor-0-0 libdecor-0-plugin-1-cairo
#   libffi-dev libflac8 libflite1 libfontconfig-dev libfontconfig1-dev
#   libfreetype-dev libfreetype6-dev libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libglib2.0-dev libglib2.0-dev-bin libgme0
#   libgoogle-perftools4 libgsm1 libice-dev libiec61883-0 libigdgmm12
#   libjack-jackd2-0 liblilv-0-0 libmfx1 libmp3lame0 libmpg123-0 libmysofa1
#   libnorm1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0
#   libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0 libpcre16-3
#   libpcre3-dev libpcre32-3 libpcrecpp0v5 libpgm-5.3-0 libpixman-1-dev
#   libpng-dev libpng-tools libpocketsphinx3 libpostproc55 libpthread-stubs0-dev
#   libpulse0 librabbitmq4 libraw1394-11 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libserd-0-0 libshine3 libsm-dev
#   libsnappy1v5 libsndfile1 libsndio7.0 libsord-0-0 libsoxr0 libspeex1
#   libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls libssh-gcrypt-4 libswresample3
#   libswscale5 libtcmalloc-minimal4 libthai-data libthai0 libtheora0
#   libtwolame0 libudfread0 libva-drm2 libva-x11-2 libva2 libvdpau1
#   libvidstab1.1 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx7
#   libwayland-cursor0 libwayland-egl1 libwebpmux3 libx11-dev libx264-163
#   libx265-199 libxau-dev libxcb-render0-dev libxcb-shm0-dev libxcb1-dev
#   libxcursor1 libxdmcp-dev libxext-dev libxrender-dev libxvidcore4 libzimg2
#   libzmq5 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers p7zip
#   p7zip-full pandoc pandoc-data pocketsphinx-en-us python3-tk tk8.6-blt2.5
#   va-driver-all vdpau-driver-all x11proto-dev xorg-sgml-doctools xtrans-dev
# The following packages will be upgraded:
#   curl libcurl4 libglib2.0-0 libglib2.0-bin python3-pip
# 5 upgraded, 152 newly installed, 0 to remove and 87 not upgraded.
# Need to get 130 MB of archives.
# After this operation, 448 MB of additional disk space will be used.
# Get:1 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-bin amd64 2.72.4-0ubuntu2.4 [80.9 kB]
# Get:2 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.4 [1465 kB]
# Get:3 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 tk8.6-blt2.5 amd64 2.5.3+dfsg-4.1build2 [643 kB]
# Get:4 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 blt amd64 2.5.3+dfsg-4.1build2 [4838 B]
# Get:5 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.20 [194 kB]
# Get:6 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.20 [289 kB]
# Get:7 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libaom3 amd64 3.3.0-1 [1748 kB]
# Get:8 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libva2 amd64 2.14.0-1 [65.0 kB]
# Get:9 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libmfx1 amd64 22.3.0-1 [3105 kB]
# Get:10 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libva-drm2 amd64 2.14.0-1 [7502 B]
# Get:11 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libva-x11-2 amd64 2.14.0-1 [12.6 kB]
# Get:12 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau1 amd64 1.4-3build2 [27.0 kB]
# Get:13 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavutil56 amd64 7:4.4.2-0ubuntu0.22.04.1 [290 kB]
# Get:14 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libcodec2-1.0 amd64 1.0.1-3 [8435 kB]
# Get:15 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libdav1d5 amd64 0.9.2-1 [463 kB]
# Get:16 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libgsm1 amd64 1.0.19-1 [27.7 kB]
# Get:17 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libmp3lame0 amd64 3.100-3build2 [141 kB]
# Get:18 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libopenjp2-7 amd64 2.4.0-6ubuntu0.2 [158 kB]
# Get:19 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libopus0 amd64 1.3.1-0.1build2 [203 kB]
# Get:20 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-gobject2 amd64 1.16.0-5ubuntu2 [19.4 kB]
# Get:21 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-common all 2.42.8+dfsg-1ubuntu0.3 [5630 B]
# Get:22 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf-2.0-0 amd64 2.42.8+dfsg-1ubuntu0.3 [148 kB]
# Get:23 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig amd64 2.13.1-4.2ubuntu5 [177 kB]
# Get:24 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libthai-data all 0.1.29-1build1 [162 kB]
# Get:25 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libdatrie1 amd64 0.2.13-2 [19.9 kB]
# Get:26 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libthai0 amd64 0.1.29-1build1 [19.2 kB]
# Get:27 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpango-1.0-0 amd64 1.50.6+ds-2ubuntu1 [230 kB]
# Get:28 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoft2-1.0-0 amd64 1.50.6+ds-2ubuntu1 [54.0 kB]
# Get:29 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangocairo-1.0-0 amd64 1.50.6+ds-2ubuntu1 [39.8 kB]
# Get:30 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-2 amd64 2.52.5+dfsg-3ubuntu0.2 [2974 kB]
# Get:31 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:32 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libsnappy1v5 amd64 1.1.8-1build3 [17.5 kB]
# Get:33 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu3 [57.9 kB]
# Get:34 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libsoxr0 amd64 0.1.3-4build2 [79.8 kB]
# Get:35 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswresample3 amd64 7:4.4.2-0ubuntu0.22.04.1 [62.2 kB]
# Get:36 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libogg0 amd64 1.3.5-0ubuntu3 [22.9 kB]
# Get:37 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu4 [209 kB]
# Get:38 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libtwolame0 amd64 0.4.0-2build2 [52.5 kB]
# Get:39 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libvorbis0a amd64 1.3.7-1build2 [99.2 kB]
# Get:40 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisenc2 amd64 1.3.7-1build2 [82.6 kB]
# Get:41 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libvpx7 amd64 1.11.0-2ubuntu2.3 [1078 kB]
# Get:42 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpmux3 amd64 1.2.2-2ubuntu0.22.04.2 [20.5 kB]
# Get:43 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libx264-163 amd64 2:0.163.3060+git5db6aa6-2build1 [591 kB]
# Get:44 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libx265-199 amd64 3.5-2 [1170 kB]
# Get:45 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:46 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi-common all 0.2.35-19 [35.5 kB]
# Get:47 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi0 amd64 0.2.35-19 [262 kB]
# Get:48 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavcodec58 amd64 7:4.4.2-0ubuntu0.22.04.1 [5567 kB]
# Get:49 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-11 amd64 2.1.2-2build2 [27.0 kB]
# Get:50 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libavc1394-0 amd64 0.5.4-5build2 [17.0 kB]
# Get:51 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libass9 amd64 1:0.15.2-1 [97.5 kB]
# Get:52 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libudfread0 amd64 1.1.2-1 [16.2 kB]
# Get:53 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libbluray2 amd64 1:1.3.1-1 [159 kB]
# Get:54 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libchromaprint1 amd64 1.5.1-2 [28.4 kB]
# Get:55 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libgme0 amd64 0.6.3-2 [127 kB]
# Get:56 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmpg123-0 amd64 1.29.3-1ubuntu0.1 [172 kB]
# Get:57 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisfile3 amd64 1.3.7-1build2 [17.1 kB]
# Get:58 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libopenmpt0 amd64 0.6.1-1 [592 kB]
# Get:59 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 librabbitmq4 amd64 0.10.0-1ubuntu2 [39.3 kB]
# Get:60 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libsrt1.4-gnutls amd64 1.4.4-4 [309 kB]
# Get:61 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-gcrypt-4 amd64 0.9.6-2ubuntu0.22.04.3 [223 kB]
# Get:62 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libnorm1 amd64 1.5.9+dfsg-2 [221 kB]
# Get:63 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libpgm-5.3-0 amd64 5.3.128~dfsg-2 [161 kB]
# Get:64 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libzmq5 amd64 4.3.4-2 [256 kB]
# Get:65 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavformat58 amd64 7:4.4.2-0ubuntu0.22.04.1 [1103 kB]
# Get:66 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:67 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libflite1 amd64 2.2-3 [13.7 MB]
# Get:68 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libserd-0-0 amd64 0.30.10-2 [40.8 kB]
# Get:69 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libsord-0-0 amd64 0.16.8-2 [21.2 kB]
# Get:70 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libsratom-0-0 amd64 0.6.8-1 [17.0 kB]
# Get:71 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 liblilv-0-0 amd64 0.24.12-2 [42.8 kB]
# Get:72 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libmysofa1 amd64 1.2.1~dfsg0-1 [1157 kB]
# Get:73 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libasyncns0 amd64 0.8-6build2 [12.8 kB]
# Get:74 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libflac8 amd64 1.3.3-2ubuntu0.2 [111 kB]
# Get:75 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsndfile1 amd64 1.0.31-2ubuntu0.1 [197 kB]
# Get:76 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [298 kB]
# Get:77 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libsphinxbase3 amd64 0.8+5prealpha+1-13build1 [126 kB]
# Get:78 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libpocketsphinx3 amd64 0.8.0+real5prealpha+1-14ubuntu1 [132 kB]
# Get:79 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpostproc55 amd64 7:4.4.2-0ubuntu0.22.04.1 [60.1 kB]
# Get:80 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libsamplerate0 amd64 0.2.2-1build1 [1359 kB]
# Get:81 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 librubberband2 amd64 2.0.0-2 [90.0 kB]
# Get:82 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswscale5 amd64 7:4.4.2-0ubuntu0.22.04.1 [180 kB]
# Get:83 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:84 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libzimg2 amd64 3.0.3+ds1-1 [241 kB]
# Get:85 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavfilter7 amd64 7:4.4.2-0ubuntu0.22.04.1 [1496 kB]
# Get:86 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcaca0 amd64 0.99.beta19-2.2ubuntu4 [224 kB]
# Get:87 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcdio19 amd64 2.1.0-3ubuntu0.2 [63.6 kB]
# Get:88 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1build3 [16.7 kB]
# Get:89 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1build3 [15.9 kB]
# Get:90 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libdc1394-25 amd64 2.2.6-4 [88.8 kB]
# Get:91 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libiec61883-0 amd64 1.2.0-4build3 [25.9 kB]
# Get:92 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libjack-jackd2-0 amd64 1.9.20~dfsg-1 [293 kB]
# Get:93 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal-data all 1:1.19.1-2build3 [164 kB]
# Get:94 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio7.0 amd64 1.8.1-1.1 [29.3 kB]
# Get:95 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal1 amd64 1:1.19.1-2build3 [535 kB]
# Get:96 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-0 amd64 0.1.0-3build1 [15.1 kB]
# Get:97 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-cursor0 amd64 1.20.0-1ubuntu0.1 [10.7 kB]
# Get:98 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-egl1 amd64 1.20.0-1ubuntu0.1 [5582 B]
# Get:99 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor1 amd64 1:1.2.0-2build4 [20.9 kB]
# Get:100 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsdl2-2.0-0 amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [582 kB]
# Get:101 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavdevice58 amd64 7:4.4.2-0ubuntu0.22.04.1 [87.5 kB]
# Get:102 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 ffmpeg amd64 7:4.4.2-0ubuntu0.22.04.1 [1696 kB]
# Get:103 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 git-lfs amd64 3.0.2-1ubuntu0.3 [3544 kB]
# Get:104 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libigdgmm12 amd64 22.1.2+ds1-1 [139 kB]
# Get:105 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 intel-media-va-driver amd64 22.3.1+dfsg1-1ubuntu2 [2283 kB]
# Get:106 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libaacs0 amd64 0.11.1-1 [64.1 kB]
# Get:107 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libbdplus0 amd64 0.2.0-1 [52.2 kB]
# Get:108 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libbrotli-dev amd64 1.0.9-2build6 [337 kB]
# Get:109 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-script-interpreter2 amd64 1.16.0-5ubuntu2 [62.0 kB]
# Get:110 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libpng-dev amd64 1.6.37-3build5 [192 kB]
# Get:111 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfreetype-dev amd64 2.11.1+dfsg-1ubuntu0.2 [555 kB]
# Get:112 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfreetype6-dev amd64 2.11.1+dfsg-1ubuntu0.2 [8290 B]
# Get:113 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libfontconfig-dev amd64 2.13.1-4.2ubuntu5 [151 kB]
# Get:114 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libfontconfig1-dev amd64 2.13.1-4.2ubuntu5 [1836 B]
# Get:115 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 xorg-sgml-doctools all 1:1.11-1.1 [10.9 kB]
# Get:116 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 x11proto-dev all 2021.5-1 [604 kB]
# Get:117 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxau-dev amd64 1:1.0.9-1build5 [9724 B]
# Get:118 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxdmcp-dev amd64 1:1.1.3-0ubuntu5 [26.5 kB]
# Get:119 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 xtrans-dev all 1.4.0-1 [68.9 kB]
# Get:120 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libpthread-stubs0-dev amd64 0.4-1build2 [5516 B]
# Get:121 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxcb1-dev amd64 1.14-3ubuntu3 [86.5 kB]
# Get:122 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-dev amd64 2:1.7.5-1ubuntu0.3 [744 kB]
# Get:123 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxrender-dev amd64 1:0.9.10-1build4 [26.7 kB]
# Get:124 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxext-dev amd64 2:1.3.4-1build1 [84.7 kB]
# Get:125 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:126 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:127 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-dev amd64 0.40.0-1ubuntu0.22.04.1 [280 kB]
# Get:128 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render0-dev amd64 1.14-3ubuntu3 [19.6 kB]
# Get:129 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shm0-dev amd64 1.14-3ubuntu3 [6848 B]
# Get:130 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Get:131 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.4 [117 kB]
# Get:132 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcre16-3 amd64 2:8.39-13ubuntu0.22.04.1 [164 kB]
# Get:133 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcre32-3 amd64 2:8.39-13ubuntu0.22.04.1 [155 kB]
# Get:134 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcrecpp0v5 amd64 2:8.39-13ubuntu0.22.04.1 [16.5 kB]
# Get:135 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcre3-dev amd64 2:8.39-13ubuntu0.22.04.1 [579 kB]
# Get:136 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.4 [1743 kB]
# Get:137 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libcairo2-dev amd64 1.16.0-5ubuntu2 [692 kB]
# Get:138 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libcmark-gfm0.29.0.gfm.3 amd64 0.29.0.gfm.3-3 [115 kB]
# Get:139 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 libcmark-gfm-extensions0.29.0.gfm.3 amd64 0.29.0.gfm.3-3 [25.1 kB]
# Get:140 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-plugin-1-cairo amd64 0.1.0-3build1 [20.4 kB]
# Get:141 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.42.8+dfsg-1ubuntu0.3 [14.2 kB]
# Get:142 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libtcmalloc-minimal4 amd64 2.9.1-0ubuntu3 [98.2 kB]
# Get:143 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libgoogle-perftools4 amd64 2.9.1-0ubuntu3 [212 kB]
# Get:144 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 libpng-tools amd64 1.6.37-3build5 [28.7 kB]
# Get:145 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:146 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 mesa-va-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [4100 kB]
# Get:147 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vdpau-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [3820 kB]
# Get:148 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 p7zip amd64 16.02+dfsg-8 [363 kB]
# Get:149 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 p7zip-full amd64 16.02+dfsg-8 [1186 kB]
# Get:150 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 pandoc-data all 2.9.2.1-3ubuntu2 [81.8 kB]
# Get:151 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 pandoc amd64 2.9.2.1-3ubuntu2 [20.3 MB]
# Get:152 http://azure.archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.5 [1306 kB]
# Get:153 http://azure.archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-tk amd64 3.10.8-1~22.04 [110 kB]
# Get:154 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 i965-va-driver amd64 2.4.1+dfsg1-1 [302 kB]
# Get:155 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 va-driver-all amd64 2.14.0-1 [3984 B]
# Get:156 http://azure.archive.ubuntu.com/ubuntu jammy/main amd64 vdpau-driver-all amd64 1.4-3build2 [4510 B]
# Get:157 http://azure.archive.ubuntu.com/ubuntu jammy/universe amd64 pocketsphinx-en-us all 0.8.0+real5prealpha+1-14ubuntu1 [27.6 MB]
# Fetched 130 MB in 3s (44.9 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 101504 files and directories currently installed.)
# Preparing to unpack .../000-libglib2.0-bin_2.72.4-0ubuntu2.4_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.4) over (2.72.4-0ubuntu2.3) ...
# Preparing to unpack .../001-libglib2.0-0_2.72.4-0ubuntu2.4_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.4) over (2.72.4-0ubuntu2.3) ...
# Selecting previously unselected package tk8.6-blt2.5.
# Preparing to unpack .../002-tk8.6-blt2.5_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Selecting previously unselected package blt.
# Preparing to unpack .../003-blt_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking blt (2.5.3+dfsg-4.1build2) ...
# Preparing to unpack .../004-curl_7.81.0-1ubuntu1.20_amd64.deb ...
# Unpacking curl (7.81.0-1ubuntu1.20) over (7.81.0-1ubuntu1.18) ...
# Preparing to unpack .../005-libcurl4_7.81.0-1ubuntu1.20_amd64.deb ...
# Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.20) over (7.81.0-1ubuntu1.18) ...
# Selecting previously unselected package libaom3:amd64.
# Preparing to unpack .../006-libaom3_3.3.0-1_amd64.deb ...
# Unpacking libaom3:amd64 (3.3.0-1) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../007-libva2_2.14.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libmfx1:amd64.
# Preparing to unpack .../008-libmfx1_22.3.0-1_amd64.deb ...
# Unpacking libmfx1:amd64 (22.3.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../009-libva-drm2_2.14.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../010-libva-x11-2_2.14.0-1_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../011-libvdpau1_1.4-3build2_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.4-3build2) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../012-libavutil56_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcodec2-1.0:amd64.
# Preparing to unpack .../013-libcodec2-1.0_1.0.1-3_amd64.deb ...
# Unpacking libcodec2-1.0:amd64 (1.0.1-3) ...
# Selecting previously unselected package libdav1d5:amd64.
# Preparing to unpack .../014-libdav1d5_0.9.2-1_amd64.deb ...
# Unpacking libdav1d5:amd64 (0.9.2-1) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../015-libgsm1_1.0.19-1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.19-1) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../016-libmp3lame0_3.100-3build2_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-3build2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../017-libopenjp2-7_2.4.0-6ubuntu0.2_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.4.0-6ubuntu0.2) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../018-libopus0_1.3.1-0.1build2_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0.1build2) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../019-libcairo-gobject2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../020-libgdk-pixbuf2.0-common_2.42.8+dfsg-1ubuntu0.3_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package libgdk-pixbuf-2.0-0:amd64.
# Preparing to unpack .../021-libgdk-pixbuf-2.0-0_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../022-fontconfig_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking fontconfig (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../023-libthai-data_0.1.29-1build1_all.deb ...
# Unpacking libthai-data (0.1.29-1build1) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../024-libdatrie1_0.2.13-2_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.13-2) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../025-libthai0_0.1.29-1build1_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../026-libpango-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../027-libpangoft2-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../028-libpangocairo-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../029-librsvg2-2_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../030-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../031-libsnappy1v5_1.1.8-1build3_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.8-1build3) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../032-libspeex1_1.2~rc1.2-1.1ubuntu3_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../033-libsoxr0_0.1.3-4build2_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.3-4build2) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../034-libswresample3_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../035-libogg0_1.3.5-0ubuntu3_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.5-0ubuntu3) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../036-libtheora0_1.1.1+dfsg.1-15ubuntu4_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../037-libtwolame0_0.4.0-2build2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2build2) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../038-libvorbis0a_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../039-libvorbisenc2_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvpx7:amd64.
# Preparing to unpack .../040-libvpx7_1.11.0-2ubuntu2.3_amd64.deb ...
# Unpacking libvpx7:amd64 (1.11.0-2ubuntu2.3) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../041-libwebpmux3_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libx264-163:amd64.
# Preparing to unpack .../042-libx264-163_2%3a0.163.3060+git5db6aa6-2build1_amd64.deb ...
# Unpacking libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Selecting previously unselected package libx265-199:amd64.
# Preparing to unpack .../043-libx265-199_3.5-2_amd64.deb ...
# Unpacking libx265-199:amd64 (3.5-2) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../044-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../045-libzvbi-common_0.2.35-19_all.deb ...
# Unpacking libzvbi-common (0.2.35-19) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../046-libzvbi0_0.2.35-19_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-19) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../047-libavcodec58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../048-libraw1394-11_2.1.2-2build2_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-2build2) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../049-libavc1394-0_0.5.4-5build2_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5build2) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../050-libass9_1%3a0.15.2-1_amd64.deb ...
# Unpacking libass9:amd64 (1:0.15.2-1) ...
# Selecting previously unselected package libudfread0:amd64.
# Preparing to unpack .../051-libudfread0_1.1.2-1_amd64.deb ...
# Unpacking libudfread0:amd64 (1.1.2-1) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../052-libbluray2_1%3a1.3.1-1_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.3.1-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../053-libchromaprint1_1.5.1-2_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.5.1-2) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../054-libgme0_0.6.3-2_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.3-2) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../055-libmpg123-0_1.29.3-1ubuntu0.1_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.29.3-1ubuntu0.1) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../056-libvorbisfile3_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../057-libopenmpt0_0.6.1-1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.6.1-1) ...
# Selecting previously unselected package librabbitmq4:amd64.
# Preparing to unpack .../058-librabbitmq4_0.10.0-1ubuntu2_amd64.deb ...
# Unpacking librabbitmq4:amd64 (0.10.0-1ubuntu2) ...
# Selecting previously unselected package libsrt1.4-gnutls:amd64.
# Preparing to unpack .../059-libsrt1.4-gnutls_1.4.4-4_amd64.deb ...
# Unpacking libsrt1.4-gnutls:amd64 (1.4.4-4) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../060-libssh-gcrypt-4_0.9.6-2ubuntu0.22.04.3_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.3) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../061-libnorm1_1.5.9+dfsg-2_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.9+dfsg-2) ...
# Selecting previously unselected package libpgm-5.3-0:amd64.
# Preparing to unpack .../062-libpgm-5.3-0_5.3.128~dfsg-2_amd64.deb ...
# Unpacking libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../063-libzmq5_4.3.4-2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.4-2) ...
# Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../064-libavformat58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../065-libbs2b0_3.1.0+dfsg-2.2build1_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../066-libflite1_2.2-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.2-3) ...
# Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../067-libserd-0-0_0.30.10-2_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.30.10-2) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../068-libsord-0-0_0.16.8-2_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.8-2) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../069-libsratom-0-0_0.6.8-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.8-1) ...
# Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../070-liblilv-0-0_0.24.12-2_amd64.deb ...
# Unpacking liblilv-0-0:amd64 (0.24.12-2) ...
# Selecting previously unselected package libmysofa1:amd64.
# Preparing to unpack .../071-libmysofa1_1.2.1~dfsg0-1_amd64.deb ...
# Unpacking libmysofa1:amd64 (1.2.1~dfsg0-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../072-libasyncns0_0.8-6build2_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6build2) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../073-libflac8_1.3.3-2ubuntu0.2_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.3-2ubuntu0.2) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../074-libsndfile1_1.0.31-2ubuntu0.1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.31-2ubuntu0.1) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../075-libpulse0_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libsphinxbase3:amd64.
# Preparing to unpack .../076-libsphinxbase3_0.8+5prealpha+1-13build1_amd64.deb ...
# Unpacking libsphinxbase3:amd64 (0.8+5prealpha+1-13build1) ...
# Selecting previously unselected package libpocketsphinx3:amd64.
# Preparing to unpack .../077-libpocketsphinx3_0.8.0+real5prealpha+1-14ubuntu1_amd64.deb ...
# Unpacking libpocketsphinx3:amd64 (0.8.0+real5prealpha+1-14ubuntu1) ...
# Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../078-libpostproc55_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpostproc55:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../079-libsamplerate0_0.2.2-1build1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.2.2-1build1) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../080-librubberband2_2.0.0-2_amd64.deb ...
# Unpacking librubberband2:amd64 (2.0.0-2) ...
# Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../081-libswscale5_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswscale5:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../082-libvidstab1.1_1.1.0-2_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2) ...
# Selecting previously unselected package libzimg2:amd64.
# Preparing to unpack .../083-libzimg2_3.0.3+ds1-1_amd64.deb ...
# Unpacking libzimg2:amd64 (3.0.3+ds1-1) ...
# Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../084-libavfilter7_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavfilter7:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../085-libcaca0_0.99.beta19-2.2ubuntu4_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2.2ubuntu4) ...
# Selecting previously unselected package libcdio19:amd64.
# Preparing to unpack .../086-libcdio19_2.1.0-3ubuntu0.2_amd64.deb ...
# Unpacking libcdio19:amd64 (2.1.0-3ubuntu0.2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../087-libcdio-cdda2_10.2+2.0.0-1build3_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+2.0.0-1build3) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../088-libcdio-paranoia2_10.2+2.0.0-1build3_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+2.0.0-1build3) ...
# Selecting previously unselected package libdc1394-25:amd64.
# Preparing to unpack .../089-libdc1394-25_2.2.6-4_amd64.deb ...
# Unpacking libdc1394-25:amd64 (2.2.6-4) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../090-libiec61883-0_1.2.0-4build3_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-4build3) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../091-libjack-jackd2-0_1.9.20~dfsg-1_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../092-libopenal-data_1%3a1.19.1-2build3_all.deb ...
# Unpacking libopenal-data (1:1.19.1-2build3) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../093-libsndio7.0_1.8.1-1.1_amd64.deb ...
# Unpacking libsndio7.0:amd64 (1.8.1-1.1) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../094-libopenal1_1%3a1.19.1-2build3_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-2build3) ...
# Selecting previously unselected package libdecor-0-0:amd64.
# Preparing to unpack .../095-libdecor-0-0_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-0:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../096-libwayland-cursor0_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../097-libwayland-egl1_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libxcursor1:amd64.
# Preparing to unpack .../098-libxcursor1_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor1:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../099-libsdl2-2.0-0_2.0.20+dfsg-2ubuntu1.22.04.1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../100-libavdevice58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavdevice58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../101-ffmpeg_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking ffmpeg (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package git-lfs.
# Preparing to unpack .../102-git-lfs_3.0.2-1ubuntu0.3_amd64.deb ...
# Unpacking git-lfs (3.0.2-1ubuntu0.3) ...
# Selecting previously unselected package libigdgmm12:amd64.
# Preparing to unpack .../103-libigdgmm12_22.1.2+ds1-1_amd64.deb ...
# Unpacking libigdgmm12:amd64 (22.1.2+ds1-1) ...
# Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../104-intel-media-va-driver_22.3.1+dfsg1-1ubuntu2_amd64.deb ...
# Unpacking intel-media-va-driver:amd64 (22.3.1+dfsg1-1ubuntu2) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../105-libaacs0_0.11.1-1_amd64.deb ...
# Unpacking libaacs0:amd64 (0.11.1-1) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../106-libbdplus0_0.2.0-1_amd64.deb ...
# Unpacking libbdplus0:amd64 (0.2.0-1) ...
# Selecting previously unselected package libbrotli-dev:amd64.
# Preparing to unpack .../107-libbrotli-dev_1.0.9-2build6_amd64.deb ...
# Unpacking libbrotli-dev:amd64 (1.0.9-2build6) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../108-libcairo-script-interpreter2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libpng-dev:amd64.
# Preparing to unpack .../109-libpng-dev_1.6.37-3build5_amd64.deb ...
# Unpacking libpng-dev:amd64 (1.6.37-3build5) ...
# Selecting previously unselected package libfreetype-dev:amd64.
# Preparing to unpack .../110-libfreetype-dev_2.11.1+dfsg-1ubuntu0.2_amd64.deb ...
# Unpacking libfreetype-dev:amd64 (2.11.1+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package libfreetype6-dev:amd64.
# Preparing to unpack .../111-libfreetype6-dev_2.11.1+dfsg-1ubuntu0.2_amd64.deb ...
# Unpacking libfreetype6-dev:amd64 (2.11.1+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package libfontconfig-dev:amd64.
# Preparing to unpack .../112-libfontconfig-dev_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking libfontconfig-dev:amd64 (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libfontconfig1-dev:amd64.
# Preparing to unpack .../113-libfontconfig1-dev_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking libfontconfig1-dev:amd64 (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../114-xorg-sgml-doctools_1%3a1.11-1.1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1.1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../115-x11proto-dev_2021.5-1_all.deb ...
# Unpacking x11proto-dev (2021.5-1) ...
# Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../116-libxau-dev_1%3a1.0.9-1build5_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-1build5) ...
# Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../117-libxdmcp-dev_1%3a1.1.3-0ubuntu5_amd64.deb ...
# Unpacking libxdmcp-dev:amd64 (1:1.1.3-0ubuntu5) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../118-xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../119-libpthread-stubs0-dev_0.4-1build2_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.4-1build2) ...
# Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../120-libxcb1-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb1-dev:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../121-libx11-dev_2%3a1.7.5-1ubuntu0.3_amd64.deb ...
# Unpacking libx11-dev:amd64 (2:1.7.5-1ubuntu0.3) ...
# Selecting previously unselected package libxrender-dev:amd64.
# Preparing to unpack .../122-libxrender-dev_1%3a0.9.10-1build4_amd64.deb ...
# Unpacking libxrender-dev:amd64 (1:0.9.10-1build4) ...
# Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../123-libxext-dev_2%3a1.3.4-1build1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.4-1build1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../124-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../125-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../126-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# ...
# Preparing to unpack .../134-libpcre3-dev_2%3a8.39-13ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpcre3-dev:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../135-libglib2.0-dev_2.72.4-0ubuntu2.4_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.4) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../136-libcairo2-dev_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libcmark-gfm0.29.0.gfm.3:amd64.
# Preparing to unpack .../137-libcmark-gfm0.29.0.gfm.3_0.29.0.gfm.3-3_amd64.deb ...
# Unpacking libcmark-gfm0.29.0.gfm.3:amd64 (0.29.0.gfm.3-3) ...
# Selecting previously unselected package libcmark-gfm-extensions0.29.0.gfm.3:amd64.
# Preparing to unpack .../138-libcmark-gfm-extensions0.29.0.gfm.3_0.29.0.gfm.3-3_amd64.deb ...
# Unpacking libcmark-gfm-extensions0.29.0.gfm.3:amd64 (0.29.0.gfm.3-3) ...
# Selecting previously unselected package libdecor-0-plugin-1-cairo:amd64.
# Preparing to unpack .../139-libdecor-0-plugin-1-cairo_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-plugin-1-cairo:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../140-libgdk-pixbuf2.0-bin_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package libtcmalloc-minimal4:amd64.
# Preparing to unpack .../141-libtcmalloc-minimal4_2.9.1-0ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4:amd64 (2.9.1-0ubuntu3) ...
# Selecting previously unselected package libgoogle-perftools4:amd64.
# Preparing to unpack .../142-libgoogle-perftools4_2.9.1-0ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4:amd64 (2.9.1-0ubuntu3) ...
# Selecting previously unselected package libpng-tools.
# Preparing to unpack .../143-libpng-tools_1.6.37-3build5_amd64.deb ...
# Unpacking libpng-tools (1.6.37-3build5) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../144-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../145-mesa-va-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../146-mesa-vdpau-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package p7zip.
# Preparing to unpack .../147-p7zip_16.02+dfsg-8_amd64.deb ...
# Unpacking p7zip (16.02+dfsg-8) ...
# Selecting previously unselected package p7zip-full.
# Preparing to unpack .../148-p7zip-full_16.02+dfsg-8_amd64.deb ...
# Unpacking p7zip-full (16.02+dfsg-8) ...
# Selecting previously unselected package pandoc-data.
# Preparing to unpack .../149-pandoc-data_2.9.2.1-3ubuntu2_all.deb ...
# Unpacking pandoc-data (2.9.2.1-3ubuntu2) ...
# Selecting previously unselected package pandoc.
# Preparing to unpack .../150-pandoc_2.9.2.1-3ubuntu2_amd64.deb ...
# Unpacking pandoc (2.9.2.1-3ubuntu2) ...
# Preparing to unpack .../151-python3-pip_22.0.2+dfsg-1ubuntu0.5_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.5) over (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-tk:amd64.
# Preparing to unpack .../152-python3-tk_3.10.8-1~22.04_amd64.deb ...
# Unpacking python3-tk:amd64 (3.10.8-1~22.04) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../153-i965-va-driver_2.4.1+dfsg1-1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../154-va-driver-all_2.14.0-1_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.14.0-1) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../155-vdpau-driver-all_1.4-3build2_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.4-3build2) ...
# Selecting previously unselected package pocketsphinx-en-us.
# Preparing to unpack .../156-pocketsphinx-en-us_0.8.0+real5prealpha+1-14ubuntu1_all.deb ...
# Unpacking pocketsphinx-en-us (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libgme0:amd64 (0.6.3-2) ...
# Setting up libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.3) ...
# Setting up libpcrecpp0v5:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libsrt1.4-gnutls:amd64 (1.4.4-4) ...
# Setting up libudfread0:amd64 (1.1.2-1) ...
# Setting up libaom3:amd64 (3.3.0-1) ...
# Setting up fontconfig (2.13.1-4.2ubuntu5) ...
# Regenerating fonts cache... done.
# Setting up librabbitmq4:amd64 (0.10.0-1ubuntu2) ...
# Setting up libraw1394-11:amd64 (2.1.2-2build2) ...
# Setting up tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Setting up libcodec2-1.0:amd64 (1.0.1-3) ...
# Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up libmpg123-0:amd64 (1.29.3-1ubuntu0.1) ...
# Setting up libogg0:amd64 (1.3.5-0ubuntu3) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.2ubuntu4) ...
# Setting up libpcre16-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Setting up libtwolame0:amd64 (0.4.0-2build2) ...
# Setting up libdatrie1:amd64 (0.2.13-2) ...
# Setting up libpng-tools (1.6.37-3build5) ...
# Setting up libgsm1:amd64 (1.0.19-1) ...
# Setting up libsoxr0:amd64 (0.1.3-4build2) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.4) ...
# Setting up libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Setting up blt (2.5.3+dfsg-4.1build2) ...
# Setting up libxcursor1:amd64 (1:1.2.0-2build4) ...
# Setting up libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libpng-dev:amd64 (1.6.37-3build5) ...
# Setting up libnorm1:amd64 (1.5.9+dfsg-2) ...
# Setting up libmysofa1:amd64 (1.2.1~dfsg0-1) ...
# Setting up libtcmalloc-minimal4:amd64 (2.9.1-0ubuntu3) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.4) ...
# Setting up python3-tk:amd64 (3.10.8-1~22.04) ...
# Setting up libigdgmm12:amd64 (22.1.2+ds1-1) ...
# Setting up libcdio19:amd64 (2.1.0-3ubuntu0.2) ...
# Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Setting up libpthread-stubs0-dev:amd64 (0.4-1build2) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build3) ...
# Setting up libflac8:amd64 (1.3.3-2ubuntu0.2) ...
# Setting up xtrans-dev (1.4.0-1) ...
# Setting up libass9:amd64 (1:0.15.2-1) ...
# Setting up libva2:amd64 (2.14.0-1) ...
# Setting up libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Setting up libopus0:amd64 (1.3.1-0.1build2) ...
# Setting up libdc1394-25:amd64 (2.2.6-4) ...
# Setting up intel-media-va-driver:amd64 (22.3.1+dfsg1-1ubuntu2) ...
# Setting up libpcre32-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Setting up libvorbis0a:amd64 (1.3.7-1build2) ...
# Setting up libaacs0:amd64 (0.11.1-1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.5) ...
# Setting up pocketsphinx-en-us (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libx265-199:amd64 (3.5-2) ...
# Setting up libsndio7.0:amd64 (1.8.1-1.1) ...
# Setting up libbdplus0:amd64 (0.2.0-1) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# Setting up libcmark-gfm0.29.0.gfm.3:amd64 (0.29.0.gfm.3-3) ...
# Setting up libflite1:amd64 (2.2-3) ...
# Setting up libva-drm2:amd64 (2.14.0-1) ...
# Setting up libasyncns0:amd64 (0.8-6build2) ...
# Setting up libvdpau1:amd64 (1.4-3build2) ...
# Setting up libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Setting up libdecor-0-0:amd64 (0.1.0-3build1) ...
# Setting up libzimg2:amd64 (3.0.3+ds1-1) ...
# Setting up libcurl4:amd64 (7.81.0-1ubuntu1.20) ...
# Setting up libopenjp2-7:amd64 (2.4.0-6ubuntu0.2) ...
# Setting up libcmark-gfm-extensions0.29.0.gfm.3:amd64 (0.29.0.gfm.3-3) ...
# Setting up libopenal-data (1:1.19.1-2build3) ...
# Setting up libthai-data (0.1.29-1build1) ...
# Setting up xorg-sgml-doctools (1:1.11-1.1) ...
# Setting up libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libvpx7:amd64 (1.11.0-2ubuntu2.3) ...
# Setting up libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# Setting up curl (7.81.0-1ubuntu1.20) ...
# Setting up libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up pandoc-data (2.9.2.1-3ubuntu2) ...
# Setting up mesa-va-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libdav1d5:amd64 (0.9.2-1) ...
# Setting up libmfx1:amd64 (22.3.0-1) ...
# Setting up libbluray2:amd64 (1:1.3.1-1) ...
# Setting up git-lfs (3.0.2-1ubuntu0.3) ...
# Setting up libsamplerate0:amd64 (0.2.2-1build1) ...
# Setting up libva-x11-2:amd64 (2.14.0-1) ...
# Setting up libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libbrotli-dev:amd64 (1.0.9-2build6) ...
# Setting up libzvbi-common (0.2.35-19) ...
# Setting up p7zip (16.02+dfsg-8) ...
# Setting up libmp3lame0:amd64 (3.100-3build2) ...
# Setting up i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Setting up libvorbisenc2:amd64 (1.3.7-1build2) ...
# Setting up libgoogle-perftools4:amd64 (2.9.1-0ubuntu3) ...
# Setting up libiec61883-0:amd64 (1.2.0-4build3) ...
# Setting up libserd-0-0:amd64 (0.30.10-2) ...
# Setting up x11proto-dev (2021.5-1) ...
# Setting up libavc1394-0:amd64 (0.5.4-5build2) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.4) ...
# Setting up mesa-vdpau-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libzvbi0:amd64 (0.2.35-19) ...
# Setting up libzmq5:amd64 (4.3.4-2) ...
# Setting up libxau-dev:amd64 (1:1.0.9-1build5) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1build3) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libpcre3-dev:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1build3) ...
# Setting up p7zip-full (16.02+dfsg-8) ...
# Setting up libopenal1:amd64 (1:1.19.1-2build3) ...
# Setting up libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libfreetype-dev:amd64 (2.11.1+dfsg-1ubuntu0.2) ...
# Setting up libthai0:amd64 (0.1.29-1build1) ...
# Setting up libvorbisfile3:amd64 (1.3.7-1build2) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu5) ...
# Setting up pandoc (2.9.2.1-3ubuntu2) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.4) ...
# Setting up va-driver-all:amd64 (2.14.0-1) ...
# Setting up libpostproc55:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up librubberband2:amd64 (2.0.0-2) ...
# Setting up libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Setting up vdpau-driver-all:amd64 (1.4-3build2) ...
# Setting up libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libsord-0-0:amd64 (0.16.8-2) ...
# Setting up libsratom-0-0:amd64 (0.6.8-1) ...
# Setting up libswscale5:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libsndfile1:amd64 (1.0.31-2ubuntu0.1) ...
# Setting up liblilv-0-0:amd64 (0.24.12-2) ...
# Setting up libopenmpt0:amd64 (0.6.1-1) ...
# Setting up libxcb1-dev:amd64 (1.14-3ubuntu3) ...
# Setting up libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libfontconfig-dev:amd64 (2.13.1-4.2ubuntu5) ...
# Setting up libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libx11-dev:amd64 (2:1.7.5-1ubuntu0.3) ...
# Setting up libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libfreetype6-dev:amd64 (2.11.1+dfsg-1ubuntu0.2) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-render0-dev:amd64 (1.14-3ubuntu3) ...
# Setting up libxext-dev:amd64 (2:1.3.4-1build1) ...
# Setting up libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up libxrender-dev:amd64 (1:0.9.10-1build4) ...
# Setting up libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libfontconfig1-dev:amd64 (2.13.1-4.2ubuntu5) ...
# Setting up libsphinxbase3:amd64 (0.8+5prealpha+1-13build1) ...
# Setting up librsvg2-2:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libpocketsphinx3:amd64 (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libdecor-0-plugin-1-cairo:amd64 (0.1.0-3build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# Setting up libchromaprint1:amd64 (1.5.1-2) ...
# Setting up libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavfilter7:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavdevice58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up ffmpeg (7:4.4.2-0ubuntu0.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for install-info (6.8-4build1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Scanning processes...
# Scanning candidates...
# Scanning linux images...
#
# The currently running kernel version is 5.15.0-1074-azure which is not the
#  expected kernel version 6.5.0-1025-azure.
#
# Restarting services...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Package configuration┌────┤ Daemons using outdated libraries ├─────┐│                                             │ │                                             │ │ Which services should be restarted?         │ │                                             │ │    [ ] dbus.service                         │ │    [*] irqbalance.service                   │ │    [ ] networkd-dispatcher.service          │ │    [*] packagekit.service                   │ │    [*] polkit.service                       │ │    [*] ssh.service                          │ │    [ ] systemd-logind.service               │ │    [ ] user@5238753.service                 │ │    [*] walinuxagent.service                 │ │                                             │ │                                             │ │          <Ok>              <Cancel>         │ │                                             │ └─────────────────────────────────────────────┘

# %%
# !sudo -S update-ca-certificates < mypassword

# %% [markdown]
# ## Install CUDA

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-ubuntu2404.pin

# %%
# !sudo -S mv cuda-ubuntu2404.pin /etc/apt/preferences.d/cuda-repository-pin-600 < mypassword

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/12.6.2/local_installers/cuda-repo-ubuntu2404-12-6-local_12.6.2-560.35.03-1_amd64.deb

# %%
# !sudo -S dpkg -i cuda-repo-ubuntu2404-12-6-local_12.6.2-560.35.03-1_amd64.deb < mypassword

# %%
# !sudo -S cp /var/cuda-repo-ubuntu2404-12-6-local/cuda-*-keyring.gpg /usr/share/keyrings/ < mypassword

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get -y install cuda-12-6 < mypassword

# %% [markdown]
# ### Install cuDNN

# %%
# !wget https://developer.download.nvidia.com/compute/cudnn/9.5.0/local_installers/cudnn-local-repo-ubuntu2404-9.5.0_1.0-1_amd64.deb

# %%
# !sudo -S dpkg -i cudnn-local-repo-ubuntu2404-9.5.0_1.0-1_amd64.deb < mypassword

# %%
# !sudo -S cp /var/cudnn-local-repo-ubuntu2404-9.5.0/cudnn-*-keyring.gpg /usr/share/keyrings/ < mypassword

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get -y install cudnn < mypassword

# %% [markdown]
# ## Install Pytorch

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/bean980310/.local/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/lib/python3/dist-packages (from torch) (2.4)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from torchvision) (1.21.5)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 20.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 80.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.8 MB/s eta 0:00:00:00:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 56.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 91.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 105.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 98.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 93.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 100.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.4 MB/s eta 0:00:00:00:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 113.8 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 91.6 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 108.0 MB/s eta 0:00:00
# Downloading torchaudio-2.5.1-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.5 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.7 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 20.3 MB/s eta 0:00:00
# WARNING: Error parsing dependencies of devscripts: Invalid version: '2.22.1ubuntu1'
# Installing collected packages: mpmath, triton, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# Successfully installed fsspec-2024.12.0 mpmath-1.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-11.0.0 sympy-1.13.1 torch-2.5.1 torchaudio-2.5.1 torchvision-0.20.1 triton-3.1.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Install Huggingface

# %%
# !pip3 install huggingface huggingface-hub transformers diffusers safetensors

# %% [markdown]
# ## Install Tensorflow

# %%
# !pip3 install tensorflow tensorboard tensorboardx

# %% [markdown]
# ## Install onnxruntime

# %%
# !pip3 install onnxruntime-gpu onnx

# %% [markdown]
# ## Install CivitAI Model Downloader

# %%
# !pip3 install civitai-model-downloader

# %% [markdown]
# ### Configure civitai api key

# %%
from huggingface_hub import notebook_login

notebook_login(new_section=False)

# %%
from civitai_downloader import login

login()

# %% [markdown]
# ## Install Docker Engine

# %%
# !sudo -S install -m 0755 -d /etc/apt/keyrings < mypassword
# !sudo -S curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc < mypassword
# !sudo -S chmod a+r /etc/apt/keyrings/docker.asc < mypassword

# %%
# !echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
  $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
  xargs -a mypassword | sudo -S tee /etc/apt/sources.list.d/docker.list > /dev/null
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin < mypassword

# %%
# !sudo -S groupadd docker < mypassword

# %%
# !sudo -S usermod -aG docker $USER < mypassword

# %% [markdown]
# ### Install NVIDIA Container toolkit

# %%
# !curl -fsSL https://nvidia.github.io/libnvidia-container/gpgkey | sudo -S gpg --dearmor -o /usr/share/keyrings/nvidia-container-toolkit-keyring.gpg < mypassword \
  && curl -s -L https://nvidia.github.io/libnvidia-container/stable/deb/nvidia-container-toolkit.list | \
    sed 's#deb https://#deb [signed-by=/usr/share/keyrings/nvidia-container-toolkit-keyring.gpg] https://#g' | \
    sudo -S tee /etc/apt/sources.list.d/nvidia-container-toolkit.list < mypassword

# %%
# !sed -i -e '/experimental/ s/^#//g' /etc/apt/sources.list.d/nvidia-container-toolkit.list

# %%
# !sudo -S apt-get update < mypassword

# %%
# !sudo -S apt-get install -y nvidia-container-toolkit < mypassword

# %%
# !sudo -S nvidia-ctk runtime configure --runtime=docker < mypassword

# %%
# !sudo -S systemctl restart docker < mypassword
