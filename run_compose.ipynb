# %% [markdown]
# ## Run Compose

# %%
# !docker compose up -d stable-diffusion-webui

# %%
# !docker compose up -d comfyui

# %%
# !docker compose up -d open-webui

# %%
# !docker compose up -d kohya_ss

# %%
# !docker compose up -d invokeai

# %%
# !docker compose up -d fooocus

# %%
# !docker compose up -d stable-diffusion-webui-forge

# %%
# !docker compose up -d sdnext

# %%
# !docker compose up -d easy-diffusion

# %%
# !docker compose up -d swarmui

# %%
# !docker compose up -d facefusion

# %%
# !docker compose up -d omost

# %%
# !docker compose up -d stable-audio-tools

# %%
# !docker compose up -d audiocraft_plus

# %% [markdown]
# ## Build Compose

# %%
# !docker compose build stable-diffusion-webui
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
# [+] Building 0/0
#  ⠋ Service stable-diffusion-webui  Bui...                                  0.1s
# [+] Building 0/1
#  ⠙ Service stable-diffusion-webui  Bui...                                  0.2s
# [+] Building 0.2s (2/3)                                          docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.2s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
# [+] Building 0/1
#  ⠹ Service stable-diffusion-webui  Bui...                                  0.3s
# [+] Building 0.3s (3/3)                                          docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
# [+] Building 0/1
#  ⠸ Service stable-diffusion-webui  Bui...                                  0.4s
# [+] Building 0.4s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
# [+] Building 0/1
#  ⠼ Service stable-diffusion-webui  Bui...                                  0.5s
# [+] Building 0/1
#  ⠴ Service stable-diffusion-webui  Bui...                                  0.6s
# [+] Building 0.6s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.2s
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                  0.7s
# [+] Building 0.7s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.3s
# [+] Building 0/1
#  ⠧ Service stable-diffusion-webui  Bui...                                  0.8s
# [+] Building 0.8s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.4s
#  => => # Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129
#  => => # kB]
# [+] Building 0/1
#  ⠇ Service stable-diffusion-webui  Bui...                                  0.9s
# [+] Building 0/1
#  ⠏ Service stable-diffusion-webui  Bui...                                  1.0s
# [+] Building 1.0s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.6s
#  => => # kB]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:3 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
#  => => # Get:4 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1226 kB]
# [+] Building 0/1
#  ⠋ Service stable-diffusion-webui  Bui...                                  1.1s
# [+] Building 1.1s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.7s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [45.2 kB]
#  => => # Get:6 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [2517 kB]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [3448 kB]
# [+] Building 0/1
#  ⠙ Service stable-diffusion-webui  Bui...                                  1.2s
# [+] Building 0/1
#  ⠹ Service stable-diffusion-webui  Bui...                                  1.3s
# [+] Building 1.3s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.9s
#  => => # Get:6 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [2517 kB]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [3448 kB]
#  => => # Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [1196 kB]
# [+] Building 1.3s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          0.9s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [3448 kB]
#  => => # Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [1196 kB]
#  => => # Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB
#  => => # ]
# [+] Building 0/1
#  ⠸ Service stable-diffusion-webui  Bui...                                  1.4s
# [+] Building 0/1
#  ⠼ Service stable-diffusion-webui  Bui...                                  1.5s
# [+] Building 1.4s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.0s
#  => => # Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [1196 kB]
#  => => # Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB
#  => => # ]
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
# [+] Building 0/1
#  ⠴ Service stable-diffusion-webui  Bui...                                  1.6s
# [+] Building 1.6s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.2s
#  => => # Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB
#  => => # ]
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                  1.7s
# [+] Building 1.7s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.3s
#  => => # Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB
#  => => # ]
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
# [+] Building 0/1
#  ⠧ Service stable-diffusion-webui  Bui...                                  1.8s
# [+] Building 1.8s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.4s
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
#  => => # Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages
#  => => # [17.5 MB]
# [+] Building 0/1
#  ⠇ Service stable-diffusion-webui  Bui...                                  1.9s
# [+] Building 0/1
#  ⠏ Service stable-diffusion-webui  Bui...                                  2.0s
# [+] Building 2.0s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.6s
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
#  => => # Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages
#  => => # [17.5 MB]
# [+] Building 0/1
#  ⠋ Service stable-diffusion-webui  Bui...                                  2.1s
# [+] Building 2.1s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.7s
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
#  => => # Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages
#  => => # [17.5 MB]
# [+] Building 0/1
#  ⠙ Service stable-diffusion-webui  Bui...                                  2.2s
# [+] Building 0/1
#  ⠹ Service stable-diffusion-webui  Bui...                                  2.3s
# [+] Building 2.3s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.9s
#  => => # Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127
#  => => #  kB]
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
#  => => # Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages
#  => => # [17.5 MB]
# [+] Building 0/1
#  ⠸ Service stable-diffusion-webui  Bui...                                  2.4s
# [+] Building 2.3s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          1.9s
#  => => # Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [179
#  => => # 2 kB]
#  => => # Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages
#  => => # [17.5 MB]
#  => => # Get:13 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Package
#  => => # s [164 kB]
# [+] Building 0/1
#  ⠼ Service stable-diffusion-webui  Bui...                                  2.5s
# [+] Building 2.5s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.1s
#  => => # Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64
#  => => #  Packages [53.3 kB]
#  => => # Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packa
#  => => # ges [2840 kB]
#  => => # Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 P
#  => => # ackages [1517 kB]
# [+] Building 0/1
#  ⠴ Service stable-diffusion-webui  Bui...                                  2.6s
# [+] Building 2.6s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.2s
#  => => # Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 P
#  => => # ackages [1517 kB]
#  => => # Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64
#  => => #  Packages [3633 kB]
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                  2.7s
# [+] Building 0/1
#  ⠧ Service stable-diffusion-webui  Bui...                                  2.8s
# [+] Building 2.8s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.4s
#  => => # Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64
#  => => #  Packages [3633 kB]
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
# [+] Building 0/1
#  ⠇ Service stable-diffusion-webui  Bui...                                  2.9s
# [+] Building 2.9s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.5s
#  => => # Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64
#  => => #  Packages [3633 kB]
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
# [+] Building 0/1
#  ⠏ Service stable-diffusion-webui  Bui...                                  3.0s
# [+] Building 0/1
#  ⠋ Service stable-diffusion-webui  Bui...                                  3.1s
# [+] Building 3.1s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.7s
#  => => # Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64
#  => => #  Packages [3633 kB]
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
# [+] Building 0/1
#  ⠙ Service stable-diffusion-webui  Bui...                                  3.2s
# [+] Building 3.2s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.8s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠹ Service stable-diffusion-webui  Bui...                                  3.3s
# [+] Building 3.3s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          2.9s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠸ Service stable-diffusion-webui  Bui...                                  3.4s
# [+] Building 0/1
#  ⠼ Service stable-diffusion-webui  Bui...                                  3.5s
# [+] Building 3.5s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          3.1s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠴ Service stable-diffusion-webui  Bui...                                  3.6s
# [+] Building 3.6s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          3.2s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                  3.7s
# [+] Building 0/1
#  ⠧ Service stable-diffusion-webui  Bui...                                  3.8s
# [+] Building 3.8s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          3.4s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠇ Service stable-diffusion-webui  Bui...                                  3.9s
# [+] Building 3.9s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          3.5s
#  => => # Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Pac
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
#  => => # Reading package lists...
# [+] Building 0/1
#  ⠏ Service stable-diffusion-webui  Bui...                                  4.0s
# [+] Building 0/1
#  ⠋ Service stable-diffusion-webui  Bui...                                  4.1s
# [+] Building 4.1s (8/11)                                         docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                          3.7s
#  => => # kages [81.4 kB]
#  => => # Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64
#  => => #  Packages [33.8 kB]
#  => => # Fetched 36.9 MB in 3s (14.8 MB/s)
# ...
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            7.7s
#  => => exporting layers                                                    7.7s
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                 80.7s
# [+] Building 80.7s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            7.8s
#  => => exporting layers                                                    7.8s
# [+] Building 0/1
#  ⠧ Service stable-diffusion-webui  Bui...                                 80.8s
# [+] Building 0/1
#  ⠇ Service stable-diffusion-webui  Bui...                                 80.9s
# [+] Building 80.9s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.0s
#  => => exporting layers                                                    8.0s
# [+] Building 0/1
#  ⠏ Service stable-diffusion-webui  Bui...                                 81.0s
# [+] Building 81.0s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.1s
#  => => exporting layers                                                    8.1s
# [+] Building 0/1
#  ⠋ Service stable-diffusion-webui  Bui...                                 81.1s
# [+] Building 0/1
#  ⠙ Service stable-diffusion-webui  Bui...                                 81.2s
# [+] Building 81.2s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.3s
#  => => exporting layers                                                    8.3s
# [+] Building 0/1
#  ⠹ Service stable-diffusion-webui  Bui...                                 81.3s
# [+] Building 81.3s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.4s
#  => => exporting layers                                                    8.4s
# [+] Building 0/1
#  ⠸ Service stable-diffusion-webui  Bui...                                 81.4s
# [+] Building 0/1
#  ⠼ Service stable-diffusion-webui  Bui...                                 81.5s
# [+] Building 81.5s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.6s
#  => => exporting layers                                                    8.6s
# [+] Building 81.5s (11/12)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.6s
#  => => exporting layers                                                    8.6s
# [+] Building 0/1
#  ⠴ Service stable-diffusion-webui  Bui...                                 81.6s
# [+] Building 0/1
#  ⠦ Service stable-diffusion-webui  Bui...                                 81.7s
# [+] Building 81.7s (12/13)                                       docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.6s
#  => => exporting layers                                                    8.6s
#  => => writing image sha256:4cd0898f28ccb0ac92d44c11789bc9c1631656d223ad1  0.0s
#  => => naming to docker.io/bean980310/stable-diffusion-webui:latest        0.0s
#  => [stable-diffusion-webui] resolving provenance for metadata file        0.0s
# [+] Building 81.7s (13/13) FINISHED                              docker:default
#  => [stable-diffusion-webui internal] load build definition from Dockerfi  0.0s
#  => => transferring dockerfile: 881B                                       0.0s
#  => WARN: InvalidDefaultArgInFrom: Default value for ARG ${BASE_IMAGE} re  0.0s
#  => [stable-diffusion-webui internal] load metadata for docker.io/pytorch  0.3s
#  => [stable-diffusion-webui auth] pytorch/pytorch:pull token for registry  0.0s
#  => [stable-diffusion-webui internal] load .dockerignore                   0.0s
#  => => transferring context: 2B                                            0.0s
#  => [stable-diffusion-webui 1/6] FROM docker.io/pytorch/pytorch:2.5.1-cud  0.0s
#  => [stable-diffusion-webui internal] load build context                   0.0s
#  => => transferring context: 862B                                          0.0s
#  => CACHED [stable-diffusion-webui 2/6] WORKDIR /app                       0.0s
#  => [stable-diffusion-webui 3/6] COPY --chmod=755 ./install.sh ./          0.1s
#  => [stable-diffusion-webui 4/6] RUN ./install.sh                         72.3s
#  => [stable-diffusion-webui 5/6] WORKDIR /app                              0.1s
#  => [stable-diffusion-webui 6/6] COPY --chmod=755 ./start.sh ./            0.1s
#  => [stable-diffusion-webui] exporting to image                            8.6s
#  => => exporting layers                                                    8.6s
#  => => writing image sha256:4cd0898f28ccb0ac92d44c11789bc9c1631656d223ad1  0.0s
#  => => naming to docker.io/bean980310/stable-diffusion-webui:latest        0.0s
#  => [stable-diffusion-webui] resolving provenance for metadata file        0.0s
# [+] Building 1/1
#  ✔ Service stable-diffusion-webui  Bui...                                 81.7s

# %%
# !docker compose build comfyui

# %%
# !docker compose build open-webui

# %%
# !docker compose build kohya_ss

# %%
# !docker compose build invokeai

# %%
# !docker compose build fooocus

# %%
# !docker compose build stable-diffusion-webui-forge

# %%
# !docker compose build sdnext

# %%
# !docker compose build easy-diffusion

# %%
# !docker compose build swarmui

# %%
# !docker compose build facefusion

# %%
# !docker compose build omost

# %%
# !docker compose build stable-audio-tools

# %%
# !docker compose build audiocraft_plus
